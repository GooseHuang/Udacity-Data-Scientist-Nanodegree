# %% [markdown]
# ### A Look at the Data
#
# In order to get a better understanding of the data we will be looking at throughout this lesson, let's take a look at some of the characteristics of the dataset.
#
# First, let's read in the data and necessary libraries.

# %%
# tata

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ALookAtTheData as t
from IPython import display
# %matplotlib inline

df = pd.read_csv('./survey_results_public.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree
#
#                                   MajorUndergrad  \
# 0                                            NaN
# 1       Computer science or software engineering
# 2       Computer science or software engineering
# 3  A non-computer-focused engineering discipline
# 4       Computer science or software engineering
#
#                                           HomeRemote  \
# 0                                                NaN
# 1              More than half, but not all, the time
# 2  Less than half the time, but at least one day ...
# 3  Less than half the time, but at least one day ...
# 4                                              Never
#
#                 CompanySize  \
# 0                       NaN
# 1        20 to 99 employees
# 2  10,000 or more employees
# 3  10,000 or more employees
# 4        10 to 19 employees
#
#                                          CompanyType      YearsProgram  \
# 0                                                NaN      2 to 3 years
# 1  Privately-held limited company, not in startup...     9 to 10 years
# 2                        Publicly-traded corporation  20 or more years
# 3  Non-profit/non-governmental organization or pr...    14 to 15 years
# 4  Privately-held limited company, not in startup...  20 or more years
#
#       YearsCodedJob YearsCodedJobPast  \
# 0               NaN               NaN
# 1               NaN               NaN
# 2  20 or more years               NaN
# 3     9 to 10 years               NaN
# 4    10 to 11 years               NaN
#
#                                        DeveloperType WebDeveloperType  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                              Other              NaN
# 3                                                NaN              NaN
# 4  Mobile developer; Graphics programming; Deskto...              NaN
#
#   MobileDeveloperType NonDeveloperType  CareerSatisfaction  JobSatisfaction  \
# 0                 NaN              NaN                 NaN              NaN
# 1                 NaN              NaN                 NaN              NaN
# 2                 NaN              NaN                 8.0              9.0
# 3                 NaN   Data scientist                 6.0              3.0
# 4                 NaN              NaN                 6.0              8.0
#
#   ExCoderReturn ExCoderNotForMe ExCoderBalance ExCoder10Years ExCoderBelonged  \
# 0           NaN             NaN            NaN            NaN             NaN
# 1           NaN             NaN            NaN            NaN             NaN
# 2           NaN             NaN            NaN            NaN             NaN
# 3           NaN             NaN            NaN            NaN             NaN
# 4           NaN             NaN            NaN            NaN             NaN
#
#   ExCoderSkills ExCoderWillNotCode ExCoderActive  \
# 0           NaN                NaN           NaN
# 1           NaN                NaN           NaN
# 2           NaN                NaN           NaN
# 3           NaN                NaN           NaN
# 4           NaN                NaN           NaN
#
#                    PronounceGIF  ProblemSolving  BuildingThings  \
# 0  With a soft "g," like "jiff"  Strongly agree  Strongly agree
# 1  With a hard "g," like "gift"             NaN             NaN
# 2  With a hard "g," like "gift"  Strongly agree  Strongly agree
# 3  With a soft "g," like "jiff"  Strongly agree  Strongly agree
# 4  With a soft "g," like "jiff"             NaN             NaN
#
#   LearningNewTech   BoringDetails     JobSecurity DiversityImportant  \
# 0           Agree        Disagree  Strongly agree              Agree
# 1             NaN             NaN             NaN                NaN
# 2  Strongly agree  Somewhat agree           Agree     Strongly agree
# 3  Strongly agree        Disagree  Somewhat agree              Agree
# 4             NaN             NaN             NaN                NaN
#
#   AnnoyingUI FriendsDevelopers   RightWrongWay UnderstandComputers  \
# 0      Agree          Disagree  Somewhat agree            Disagree
# 1        NaN               NaN             NaN                 NaN
# 2      Agree    Somewhat agree        Disagree            Disagree
# 3      Agree             Agree  Somewhat agree   Strongly disagree
# 4        NaN               NaN             NaN                 NaN
#
#       SeriousWork InvestTimeTools        WorkPayCare KinshipDevelopers  \
# 0  Strongly agree  Strongly agree  Strongly disagree             Agree
# 1             NaN             NaN                NaN               NaN
# 2           Agree  Somewhat agree           Disagree    Somewhat agree
# 3  Strongly agree           Agree           Disagree    Strongly agree
# 4             NaN             NaN                NaN               NaN
#
#   ChallengeMyself    CompetePeers ChangeWorld  \
# 0           Agree        Disagree       Agree
# 1             NaN             NaN         NaN
# 2           Agree        Disagree       Agree
# 3  Strongly agree  Somewhat agree       Agree
# 4             NaN             NaN         NaN
#
#                                     JobSeekingStatus  HoursPerWeek  \
# 0  I'm not actively looking, but I am open to new...           0.0
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                    I am actively looking for a job           5.0
# 4                                                NaN           NaN
#
#                   LastNewJob   AssessJobIndustry       AssessJobRole  \
# 0      Not applicable/ never      Very important      Very important
# 1                        NaN                 NaN                 NaN
# 2                        NaN                 NaN                 NaN
# 3  Between 2 and 4 years ago  Somewhat important  Somewhat important
# 4                        NaN                 NaN                 NaN
#
#          AssessJobExp   AssessJobDept   AssessJobTech AssessJobProjects  \
# 0           Important  Very important  Very important    Very important
# 1                 NaN             NaN             NaN               NaN
# 2                 NaN             NaN             NaN               NaN
# 3  Somewhat important       Important       Important    Very important
# 4                 NaN             NaN             NaN               NaN
#
#   AssessJobCompensation AssessJobOffice AssessJobCommute     AssessJobRemote  \
# 0             Important  Very important   Very important      Very important
# 1                   NaN             NaN              NaN                 NaN
# 2                   NaN             NaN              NaN                 NaN
# 3             Important  Very important        Important  Somewhat important
# 4                   NaN             NaN              NaN                 NaN
#
#      AssessJobLeaders AssessJobProfDevel  AssessJobDiversity  \
# 0      Very important     Very important  Somewhat important
# 1                 NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 3  Not very important     Very important           Important
# 4                 NaN                NaN                 NaN
#
#      AssessJobProduct   AssessJobFinances  \
# 0  Not very important  Somewhat important
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3      Very important      Very important
# 4                 NaN                 NaN
#
#                                    ImportantBenefits ClickyKeys  \
# 0   Stock options; Vacation/days off; Remote options        Yes
# 1                                                NaN         No
# 2                                                NaN        Yes
# 3  Stock options; Annual bonus; Health benefits; ...        Yes
# 4                                                NaN        NaN
#
#         JobProfile ResumePrompted  \
# 0            Other            NaN
# 1            Other            NaN
# 2              NaN            NaN
# 3  LinkedIn; Other            NaN
# 4              NaN            NaN
#
#                                        LearnedHiring  \
# 0                                                NaN
# 1                                     Some other way
# 2                                                NaN
# 3  A friend, family member, or former colleague t...
# 4                                                NaN
#
#   ImportantHiringAlgorithms ImportantHiringTechExp  \
# 0                 Important              Important
# 1                 Important              Important
# 2                       NaN                    NaN
# 3        Somewhat important     Somewhat important
# 4                       NaN                    NaN
#
#   ImportantHiringCommunication ImportantHiringOpenSource ImportantHiringPMExp  \
# 0                    Important        Somewhat important            Important
# 1                    Important                 Important   Somewhat important
# 2                          NaN                       NaN                  NaN
# 3               Very important            Very important   Somewhat important
# 4                          NaN                       NaN                  NaN
#
#   ImportantHiringCompanies ImportantHiringTitles ImportantHiringEducation  \
# 0       Not very important    Not very important     Not at all important
# 1       Somewhat important    Not very important       Somewhat important
# 2                      NaN                   NaN                      NaN
# 3       Somewhat important    Not very important       Not very important
# 4                      NaN                   NaN                      NaN
#
#    ImportantHiringRep ImportantHiringGettingThingsDone  \
# 0  Somewhat important                   Very important
# 1  Not very important                   Very important
# 2                 NaN                              NaN
# 3           Important                   Very important
# 4                 NaN                              NaN
#
#                       Currency                        Overpaid TabsSpaces  \
# 0                          NaN                             NaN       Tabs
# 1  British pounds sterling (£)                             NaN     Spaces
# 2  British pounds sterling (£)  Neither underpaid nor overpaid     Spaces
# 3                          NaN                             NaN     Spaces
# 4                          NaN                             NaN        NaN
#
#    EducationImportant                                     EducationTypes  \
# 0                 NaN           Online course; Open source contributions
# 1                 NaN  Online course; Self-taught; Hackathon; Open so...
# 2  Not very important  Self-taught; Coding competition; Hackathon; Op...
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
#
#                                      SelfTaughtTypes TimeAfterBootcamp  \
# 0                                                NaN               NaN
# 1  Official documentation; Stack Overflow Q&A; Other               NaN
# 2  Official documentation; Trade book; Textbook; ...               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
#
#   CousinEducation WorkStart             HaveWorkedLanguage  \
# 0             NaN   6:00 AM                          Swift
# 1             NaN  10:00 AM  JavaScript; Python; Ruby; SQL
# 2             NaN   9:00 AM              Java; PHP; Python
# 3             NaN   9:00 AM         Matlab; Python; R; SQL
# 4             NaN       NaN                            NaN
#
#           WantWorkLanguage HaveWorkedFramework       WantWorkFramework  \
# 0                    Swift                 NaN                     NaN
# 1  Java; Python; Ruby; SQL           .NET Core               .NET Core
# 2          C; Python; Rust                 NaN                     NaN
# 3   Matlab; Python; R; SQL               React  Hadoop; Node.js; React
# 4                      NaN                 NaN                     NaN
#
#                           HaveWorkedDatabase  \
# 0                                        NaN
# 1                              MySQL; SQLite
# 2                                      MySQL
# 3  MongoDB; Redis; SQL Server; MySQL; SQLite
# 4                                        NaN
#
#                             WantWorkDatabase  \
# 0                                        NaN
# 1                              MySQL; SQLite
# 2                                        NaN
# 3  MongoDB; Redis; SQL Server; MySQL; SQLite
# 4                                        NaN
#
#                                   HaveWorkedPlatform  \
# 0                                                iOS
# 1                          Amazon Web Services (AWS)
# 2                                                NaN
# 3  Windows Desktop; Linux Desktop; Mac OS; Amazon...
# 4                                                NaN
#
#                                     WantWorkPlatform  \
# 0                                                iOS
# 1  Linux Desktop; Raspberry Pi; Amazon Web Servic...
# 2                                                NaN
# 3  Windows Desktop; Linux Desktop; Mac OS; Amazon...
# 4                                                NaN
#
#                                                  IDE  \
# 0                                        Atom; Xcode
# 1  Atom; Notepad++; Vim; PyCharm; RubyMine; Visua...
# 2                        Sublime Text; Vim; IntelliJ
# 3  Notepad++; Sublime Text; TextMate; Vim; IPytho...
# 4                                                NaN
#
#                                  AuditoryEnvironment  \
# 0                                 Turn on some music
# 1  Put on some ambient sounds (e.g. whale songs, ...
# 2                                 Turn on some music
# 3                                 Turn on some music
# 4                                                NaN
#
#                                  Methodology VersionControl  \
# 0                                        NaN            NaN
# 1                                        NaN            Git
# 2  Agile; Lean; Scrum; Extreme; Pair; Kanban      Mercurial
# 3                                      Agile            Git
# 4                                        NaN            NaN
#
#             CheckInCode          ShipIt OtherPeoplesCode  ProjectManagement  \
# 0                   NaN             NaN              NaN                NaN
# 1  Multiple times a day           Agree         Disagree  Strongly disagree
# 2  Multiple times a day           Agree         Disagree           Disagree
# 3  Multiple times a day  Somewhat agree            Agree     Somewhat agree
# 4                   NaN             NaN              NaN                NaN
#
#    EnjoyDebugging       InTheZone DifficultCommunication  CollaborateRemote  \
# 0             NaN             NaN                    NaN                NaN
# 1           Agree  Somewhat agree               Disagree  Strongly disagree
# 2           Agree           Agree               Disagree     Somewhat agree
# 3  Somewhat agree  Strongly agree               Disagree     Somewhat agree
# 4             NaN             NaN                    NaN                NaN
#
#                                         MetricAssess  \
# 0                                                NaN
# 1  Customer satisfaction; On time/in budget; Peer...
# 2  Customer satisfaction; Benchmarked product per...
# 3                                                NaN
# 4                                                NaN
#
#   EquipmentSatisfiedMonitors EquipmentSatisfiedCPU EquipmentSatisfiedRAM  \
# 0         Somewhat satisfied    Not very satisfied  Not at all satisfied
# 1         Not very satisfied             Satisfied             Satisfied
# 2             Very satisfied    Somewhat satisfied             Satisfied
# 3                        NaN                   NaN                   NaN
# 4                  Satisfied             Satisfied             Satisfied
#
#   EquipmentSatisfiedStorage EquipmentSatisfiedRW   InfluenceInternet  \
# 0            Very satisfied            Satisfied  Not very satisfied
# 1                 Satisfied   Somewhat satisfied           Satisfied
# 2                 Satisfied   Somewhat satisfied      Very satisfied
# 3                       NaN                  NaN                 NaN
# 4                 Satisfied            Satisfied           Satisfied
#
#   InfluenceWorkstation    InfluenceHardware     InfluenceServers  \
# 0                  NaN                  NaN                  NaN
# 1  No influence at all  No influence at all  No influence at all
# 2   A lot of influence       Some influence       Some influence
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#     InfluenceTechStack    InfluenceDeptTech    InfluenceVizTools  \
# 0                  NaN                  NaN                  NaN
# 1  No influence at all  No influence at all  No influence at all
# 2       Some influence   A lot of influence       Some influence
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#      InfluenceDatabase       InfluenceCloud InfluenceConsultants  \
# 0                  NaN                  NaN                  NaN
# 1  No influence at all  No influence at all  No influence at all
# 2       Some influence       Some influence       Some influence
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#   InfluenceRecruitment InfluenceCommunication  \
# 0                  NaN                    NaN
# 1  No influence at all    No influence at all
# 2       Some influence         Some influence
# 3                  NaN                    NaN
# 4                  NaN                    NaN
#
#                               StackOverflowDescribes  \
# 0  I have created a CV or Developer Story on Stac...
# 1  I have created a CV or Developer Story on Stac...
# 2  I have created a CV or Developer Story on Stac...
# 3  I have created a CV or Developer Story on Stac...
# 4                                                NaN
#
#    StackOverflowSatisfaction  \
# 0                        9.0
# 1                        8.0
# 2                        8.0
# 3                       10.0
# 4                        NaN
#
#                                 StackOverflowDevices StackOverflowFoundAnswer  \
# 0                                   Desktop; iOS app  At least once each week
# 1  Desktop; iOS browser; iOS app; Android browser...            Several times
# 2                      Desktop; iOS browser; iOS app            Once or twice
# 3                      Desktop; iOS browser; iOS app  At least once each week
# 4                                                NaN                      NaN
#
#   StackOverflowCopiedCode  StackOverflowJobListing StackOverflowCompanyPage  \
# 0     Haven't done at all            Once or twice      Haven't done at all
# 1           Several times            Once or twice            Once or twice
# 2     Haven't done at all      Haven't done at all      Haven't done at all
# 3           Several times  At least once each week            Several times
# 4                     NaN                      NaN                      NaN
#
#     StackOverflowJobSearch StackOverflowNewQuestion     StackOverflowAnswer  \
# 0      Haven't done at all            Several times           Several times
# 1            Once or twice      Haven't done at all           Several times
# 2      Haven't done at all      Haven't done at all  At least once each day
# 3  At least once each week            Several times  At least once each day
# 4                      NaN                      NaN                     NaN
#
#      StackOverflowMetaChat StackOverflowAdsRelevant  \
# 0            Once or twice           Somewhat agree
# 1  At least once each week                 Disagree
# 2   At least once each day                 Disagree
# 3   At least once each day                    Agree
# 4                      NaN                      NaN
#
#   StackOverflowAdsDistracting StackOverflowModeration StackOverflowCommunity  \
# 0           Strongly disagree       Strongly disagree         Strongly agree
# 1           Strongly disagree       Strongly disagree         Strongly agree
# 2                    Disagree       Strongly disagree         Strongly agree
# 3           Strongly disagree       Strongly disagree         Strongly agree
# 4                         NaN                     NaN                    NaN
#
#   StackOverflowHelpful StackOverflowBetter StackOverflowWhatDo  \
# 0                Agree      Strongly agree      Strongly agree
# 1                Agree      Strongly agree      Strongly agree
# 2                Agree               Agree               Agree
# 3       Strongly agree               Agree      Strongly agree
# 4                  NaN                 NaN                 NaN
#
#   StackOverflowMakeMoney Gender HighestEducationParents  \
# 0      Strongly disagree   Male             High school
# 1      Strongly disagree   Male       A master's degree
# 2               Disagree   Male   A professional degree
# 3               Disagree   Male       A doctoral degree
# 4                    NaN    NaN                     NaN
#
#                            Race         SurveyLong QuestionsInteresting  \
# 0  White or of European descent  Strongly disagree       Strongly agree
# 1  White or of European descent     Somewhat agree       Somewhat agree
# 2  White or of European descent     Somewhat agree                Agree
# 3  White or of European descent              Agree                Agree
# 4                           NaN                NaN                  NaN
#
#   QuestionsConfusing InterestedAnswers    Salary  ExpectedSalary
# 0           Disagree    Strongly agree       NaN             NaN
# 1           Disagree    Strongly agree       NaN         37500.0
# 2           Disagree             Agree  113750.0             NaN
# 3     Somewhat agree    Strongly agree       NaN             NaN
# 4                NaN               NaN       NaN             NaN

# %%
## Pandas display all rows
pd.set_option('display.max_rows', None)
# Display all columns of a dataframe
pd.options.display.max_columns = None

# %% [markdown]
# As you work through the notebook(s) in this and future parts of this program, you will see some consistency in how to test your solutions to assure they match what we achieved!  In every environment, there is a solution file and a test file.  There will be checks for each solution built into each notebook, but if you get stuck, you may also open the solution notebook to see how we find any of the solutions.  Let's take a look at an example.
#
# ### Question 1
#
# **1.** Provide the number of rows and columns in this dataset.

# %%
# We solved this one for you by providing the number of rows and columns:
# You can see how we are prompted that we solved for the number of rows and cols correctly!

num_rows = df.shape[0] #Provide the number of rows in the dataset
num_cols = df.shape[1] #Provide the number of columns in the dataset

t.check_rows_cols(num_rows, num_cols)
# Out:
# Nice job there are 19102 rows in the dataset!
# Nice job there are 154 columns in the dataset!

# %%
# If we made a mistake - a different prompt will appear

flipped_num_rows = df.shape[1] #Provide the number of rows in the dataset
flipped_num_cols = df.shape[0] #Provide the number of columns in the dataset

t.check_rows_cols(flipped_num_rows, flipped_num_cols)
# Out:
# That doesn't look like what we were expecting for the number of rows.
# That doesn't look like what we were expecting for the number of columns.

# %%
# If you want to know more about what the test function is expecting, 
# you can read the documentation the same way as any other funtion

t.check_rows_cols?

# %% [markdown]
# Now that you are familiar with how to test your code - let's have you answer your first question:
#
# ### Question 2
#
# **2.** Which columns had no missing values? Provide a set of column names that have no missing values.

# %%
df.describe(include='all')
# Out:
#           Respondent            Professional               ProgramHobby  \
# count   19102.000000                   19102                      19102
# unique           NaN                       5                          4
# top              NaN  Professional developer  Yes, I program as a hobby
# freq             NaN                   13774                       9260
# mean     9551.500000                     NaN                        NaN
# std      5514.416757                     NaN                        NaN
# min         1.000000                     NaN                        NaN
# 25%      4776.250000                     NaN                        NaN
# 50%      9551.500000                     NaN                        NaN
# 75%     14326.750000                     NaN                        NaN
# max     19102.000000                     NaN                        NaN
#
#               Country University    EmploymentStatus    FormalEducation  \
# count           19102      19102               19102              19102
# unique            165          4                   7                  9
# top     United States         No  Employed full-time  Bachelor's degree
# freq             4364      14233               13655               8099
# mean              NaN        NaN                 NaN                NaN
# std               NaN        NaN                 NaN                NaN
# min               NaN        NaN                 NaN                NaN
# 25%               NaN        NaN                 NaN                NaN
# 50%               NaN        NaN                 NaN                NaN
# 75%               NaN        NaN                 NaN                NaN
# max               NaN        NaN                 NaN                NaN
#
#                                   MajorUndergrad             HomeRemote  \
# count                                      15899                  16471
# unique                                        16                      7
# top     Computer science or software engineering  A few days each month
# freq                                        8098                   5876
# mean                                         NaN                    NaN
# std                                          NaN                    NaN
# min                                          NaN                    NaN
# 25%                                          NaN                    NaN
# 50%                                          NaN                    NaN
# 75%                                          NaN                    NaN
# max                                          NaN                    NaN
#
#                CompanySize                                        CompanyType  \
# count                14653                                              14609
# unique                  10                                                 11
# top     20 to 99 employees  Privately-held limited company, not in startup...
# freq                  3214                                               6283
# mean                   NaN                                                NaN
# std                    NaN                                                NaN
# min                    NaN                                                NaN
# 25%                    NaN                                                NaN
# 50%                    NaN                                                NaN
# 75%                    NaN                                                NaN
# max                    NaN                                                NaN
#
#             YearsProgram YearsCodedJob YearsCodedJobPast  DeveloperType  \
# count              19005         15391               349          13772
# unique                21            21                21           1024
# top     20 or more years  1 to 2 years  20 or more years  Web developer
# freq                3471          1867                67           4283
# mean                 NaN           NaN               NaN            NaN
# std                  NaN           NaN               NaN            NaN
# min                  NaN           NaN               NaN            NaN
# 25%                  NaN           NaN               NaN            NaN
# 50%                  NaN           NaN               NaN            NaN
# 75%                  NaN           NaN               NaN            NaN
# max                  NaN           NaN               NaN            NaN
#
#                 WebDeveloperType MobileDeveloperType NonDeveloperType  \
# count                       4286                 556             1688
# unique                         3                   8               86
# top     Full stack Web developer             Android            Other
# freq                        2729                 220              450
# mean                         NaN                 NaN              NaN
# std                          NaN                 NaN              NaN
# min                          NaN                 NaN              NaN
# 25%                          NaN                 NaN              NaN
# 50%                          NaN                 NaN              NaN
# 75%                          NaN                 NaN              NaN
# max                          NaN                 NaN              NaN
#
#         CareerSatisfaction  JobSatisfaction ExCoderReturn    ExCoderNotForMe  \
# count         16102.000000     15253.000000           335                332
# unique                 NaN              NaN             5                  5
# top                    NaN              NaN         Agree  Strongly disagree
# freq                   NaN              NaN            87                121
# mean              7.343932         7.000721           NaN                NaN
# std               1.919330         2.128648           NaN                NaN
# min               0.000000         0.000000           NaN                NaN
# 25%               6.000000         6.000000           NaN                NaN
# 50%               8.000000         7.000000           NaN                NaN
# 75%               9.000000         8.000000           NaN                NaN
# max              10.000000        10.000000           NaN                NaN
#
#        ExCoderBalance ExCoder10Years ExCoderBelonged   ExCoderSkills  \
# count             335            336             335             336
# unique              5              5               5               5
# top          Disagree       Disagree        Disagree  Somewhat agree
# freq              100             93             129              94
# mean              NaN            NaN             NaN             NaN
# std               NaN            NaN             NaN             NaN
# min               NaN            NaN             NaN             NaN
# 25%               NaN            NaN             NaN             NaN
# 50%               NaN            NaN             NaN             NaN
# 75%               NaN            NaN             NaN             NaN
# max               NaN            NaN             NaN             NaN
#
#        ExCoderWillNotCode ExCoderActive                  PronounceGIF  \
# count                 332           335                         18940
# unique                  5             5                             4
# top              Disagree         Agree  With a hard "g," like "gift"
# freq                  107           110                         12694
# mean                  NaN           NaN                           NaN
# std                   NaN           NaN                           NaN
# min                   NaN           NaN                           NaN
# 25%                   NaN           NaN                           NaN
# 50%                   NaN           NaN                           NaN
# 75%                   NaN           NaN                           NaN
# max                   NaN           NaN                           NaN
#
#         ProblemSolving  BuildingThings LearningNewTech BoringDetails  \
# count            12220           12201           12216         12190
# unique               5               5               5             5
# top     Strongly agree  Strongly agree  Strongly agree      Disagree
# freq              6941            6662            5711          4808
# mean               NaN             NaN             NaN           NaN
# std                NaN             NaN             NaN           NaN
# min                NaN             NaN             NaN           NaN
# 25%                NaN             NaN             NaN           NaN
# 50%                NaN             NaN             NaN           NaN
# 75%                NaN             NaN             NaN           NaN
# max                NaN             NaN             NaN           NaN
#
#        JobSecurity DiversityImportant      AnnoyingUI FriendsDevelopers  \
# count        12198              12079           12140             12143
# unique           5                  5               5                 5
# top          Agree              Agree  Strongly agree          Disagree
# freq          5208               4738            4855              3740
# mean           NaN                NaN             NaN               NaN
# std            NaN                NaN             NaN               NaN
# min            NaN                NaN             NaN               NaN
# 25%            NaN                NaN             NaN               NaN
# 50%            NaN                NaN             NaN               NaN
# 75%            NaN                NaN             NaN               NaN
# max            NaN                NaN             NaN               NaN
#
#          RightWrongWay UnderstandComputers SeriousWork InvestTimeTools  \
# count            12112               12135       12132           12059
# unique               5                   5           5               5
# top     Somewhat agree            Disagree       Agree           Agree
# freq              3888                3137        5902            4827
# mean               NaN                 NaN         NaN             NaN
# std                NaN                 NaN         NaN             NaN
# min                NaN                 NaN         NaN             NaN
# 25%                NaN                 NaN         NaN             NaN
# 50%                NaN                 NaN         NaN             NaN
# 75%                NaN                 NaN         NaN             NaN
# max                NaN                 NaN         NaN             NaN
#
#        WorkPayCare KinshipDevelopers ChallengeMyself CompetePeers  \
# count        12087             11980           12089        12034
# unique           5                 5               5            5
# top       Disagree             Agree           Agree     Disagree
# freq          5570              5048            5839         3956
# mean           NaN               NaN             NaN          NaN
# std            NaN               NaN             NaN          NaN
# min            NaN               NaN             NaN          NaN
# 25%            NaN               NaN             NaN          NaN
# 50%            NaN               NaN             NaN          NaN
# 75%            NaN               NaN             NaN          NaN
# max            NaN               NaN             NaN          NaN
#
#            ChangeWorld                                   JobSeekingStatus  \
# count            12077                                              12852
# unique               5                                                  3
# top     Somewhat agree  I'm not actively looking, but I am open to new...
# freq              3754                                               8026
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#         HoursPerWeek            LastNewJob AssessJobIndustry AssessJobRole  \
# count    7721.000000                 12578              8401          8403
# unique           NaN                     5                 5             5
# top              NaN  Less than a year ago         Important     Important
# freq             NaN                  3798              2760          3164
# mean        3.685922                   NaN               NaN           NaN
# std         7.330691                   NaN               NaN           NaN
# min         0.000000                   NaN               NaN           NaN
# 25%         0.000000                   NaN               NaN           NaN
# 50%         1.000000                   NaN               NaN           NaN
# 75%         3.000000                   NaN               NaN           NaN
# max        40.000000                   NaN               NaN           NaN
#
#        AssessJobExp AssessJobDept AssessJobTech AssessJobProjects  \
# count          8398          8390          8420              8412
# unique            5             5             5                 5
# top       Important     Important     Important         Important
# freq           3790          3307          3503              3722
# mean            NaN           NaN           NaN               NaN
# std             NaN           NaN           NaN               NaN
# min             NaN           NaN           NaN               NaN
# 25%             NaN           NaN           NaN               NaN
# 50%             NaN           NaN           NaN               NaN
# 75%             NaN           NaN           NaN               NaN
# max             NaN           NaN           NaN               NaN
#
#        AssessJobCompensation AssessJobOffice AssessJobCommute  \
# count                   8407            8336             8331
# unique                     5               5                5
# top                Important       Important        Important
# freq                    3779            3815             3208
# mean                     NaN             NaN              NaN
# std                      NaN             NaN              NaN
# min                      NaN             NaN              NaN
# 25%                      NaN             NaN              NaN
# 50%                      NaN             NaN              NaN
# 75%                      NaN             NaN              NaN
# max                      NaN             NaN              NaN
#
#            AssessJobRemote AssessJobLeaders AssessJobProfDevel  \
# count                 8351             8330               8341
# unique                   5                5                  5
# top     Somewhat important        Important          Important
# freq                  2347             2817               3575
# mean                   NaN              NaN                NaN
# std                    NaN              NaN                NaN
# min                    NaN              NaN                NaN
# 25%                    NaN              NaN                NaN
# 50%                    NaN              NaN                NaN
# 75%                    NaN              NaN                NaN
# max                    NaN              NaN                NaN
#
#         AssessJobDiversity AssessJobProduct AssessJobFinances  \
# count                 8324             8334              8351
# unique                   5                5                 5
# top     Somewhat important        Important         Important
# freq                  2611             2947              3364
# mean                   NaN              NaN               NaN
# std                    NaN              NaN               NaN
# min                    NaN              NaN               NaN
# 25%                    NaN              NaN               NaN
# 50%                    NaN              NaN               NaN
# 75%                    NaN              NaN               NaN
# max                    NaN              NaN               NaN
#
#        ImportantBenefits ClickyKeys JobProfile  \
# count              11570      15358       9190
# unique              2432          2        270
# top        None of these        Yes   LinkedIn
# freq                 248       8297       5660
# mean                 NaN        NaN        NaN
# std                  NaN        NaN        NaN
# min                  NaN        NaN        NaN
# 25%                  NaN        NaN        NaN
# 50%                  NaN        NaN        NaN
# 75%                  NaN        NaN        NaN
# max                  NaN        NaN        NaN
#
#                                ResumePrompted  \
# count                                    8704
# unique                                      8
# top     I was just giving it a regular update
# freq                                     2693
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                                       NaN
#
#                                             LearnedHiring  \
# count                                                9183
# unique                                                  8
# top     A friend, family member, or former colleague t...
# freq                                                 2520
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        ImportantHiringAlgorithms ImportantHiringTechExp  \
# count                      10890                  10894
# unique                         5                      5
# top                    Important              Important
# freq                        4463                   4030
# mean                         NaN                    NaN
# std                          NaN                    NaN
# min                          NaN                    NaN
# 25%                          NaN                    NaN
# 50%                          NaN                    NaN
# 75%                          NaN                    NaN
# max                          NaN                    NaN
#
#        ImportantHiringCommunication ImportantHiringOpenSource  \
# count                         10879                     10864
# unique                            5                         5
# top                       Important        Somewhat important
# freq                           4991                      4075
# mean                            NaN                       NaN
# std                             NaN                       NaN
# min                             NaN                       NaN
# 25%                             NaN                       NaN
# 50%                             NaN                       NaN
# 75%                             NaN                       NaN
# max                             NaN                       NaN
#
#        ImportantHiringPMExp ImportantHiringCompanies ImportantHiringTitles  \
# count                 10869                    10851                 10859
# unique                    5                        5                     5
# top      Somewhat important       Somewhat important    Somewhat important
# freq                   3864                     4487                  4075
# mean                    NaN                      NaN                   NaN
# std                     NaN                      NaN                   NaN
# min                     NaN                      NaN                   NaN
# 25%                     NaN                      NaN                   NaN
# 50%                     NaN                      NaN                   NaN
# 75%                     NaN                      NaN                   NaN
# max                     NaN                      NaN                   NaN
#
#        ImportantHiringEducation  ImportantHiringRep  \
# count                     10883               10878
# unique                        5                   5
# top          Somewhat important  Not very important
# freq                       4204                4211
# mean                        NaN                 NaN
# std                         NaN                 NaN
# min                         NaN                 NaN
# 25%                         NaN                 NaN
# 50%                         NaN                 NaN
# 75%                         NaN                 NaN
# max                         NaN                 NaN
#
#        ImportantHiringGettingThingsDone          Currency            Overpaid  \
# count                             10849              8032                5184
# unique                                5                17                   5
# top                           Important  U.S. dollars ($)  Somewhat underpaid
# freq                               4878              2701                2346
# mean                                NaN               NaN                 NaN
# std                                 NaN               NaN                 NaN
# min                                 NaN               NaN                 NaN
# 25%                                 NaN               NaN                 NaN
# 50%                                 NaN               NaN                 NaN
# 75%                                 NaN               NaN                 NaN
# max                                 NaN               NaN                 NaN
#
#        TabsSpaces  EducationImportant EducationTypes  \
# count       14305                9065          11465
# unique          3                   5            367
# top        Spaces  Somewhat important    Self-taught
# freq         5877                2453           1380
# mean          NaN                 NaN            NaN
# std           NaN                 NaN            NaN
# min           NaN                 NaN            NaN
# 25%           NaN                 NaN            NaN
# 50%           NaN                 NaN            NaN
# 75%           NaN                 NaN            NaN
# max           NaN                 NaN            NaN
#
#                                           SelfTaughtTypes  \
# count                                               10173
# unique                                                791
# top     Official documentation; Trade book; Stack Over...
# freq                                                  437
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                         TimeAfterBootcamp  \
# count                                                 882
# unique                                                  9
# top     I already had a job as a developer when I star...
# freq                                                  423
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                           CousinEducation WorkStart  \
# count                                                6906     13523
# unique                                                601        24
# top     Take online courses; Buy books and work throug...   9:00 AM
# freq                                                  192      3570
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN
#
#          HaveWorkedLanguage WantWorkLanguage HaveWorkedFramework  \
# count                 13526            12523                7294
# unique                 3909             5059                 202
# top     C#; JavaScript; SQL       JavaScript           .NET Core
# freq                    514              233                1089
# mean                    NaN              NaN                 NaN
# std                     NaN              NaN                 NaN
# min                     NaN              NaN                 NaN
# 25%                     NaN              NaN                 NaN
# 50%                     NaN              NaN                 NaN
# 75%                     NaN              NaN                 NaN
# max                     NaN              NaN                 NaN
#
#        WantWorkFramework HaveWorkedDatabase WantWorkDatabase  \
# count               8499              10792             9159
# unique               322                205              222
# top            .NET Core         SQL Server       SQL Server
# freq                 798               1559              792
# mean                 NaN                NaN              NaN
# std                  NaN                NaN              NaN
# min                  NaN                NaN              NaN
# 25%                  NaN                NaN              NaN
# 50%                  NaN                NaN              NaN
# 75%                  NaN                NaN              NaN
# max                  NaN                NaN              NaN
#
#        HaveWorkedPlatform           WantWorkPlatform  \
# count               10580                      10158
# unique               1099                       1249
# top       Windows Desktop  Amazon Web Services (AWS)
# freq                 1243                        688
# mean                  NaN                        NaN
# std                   NaN                        NaN
# min                   NaN                        NaN
# 25%                   NaN                        NaN
# 50%                   NaN                        NaN
# 75%                   NaN                        NaN
# max                   NaN                        NaN
#
#                              IDE AuditoryEnvironment   Methodology  \
# count                      13197               13451          9587
# unique                      2490                   6           536
# top     Notepad++; Visual Studio  Turn on some music  Agile; Scrum
# freq                         610                7956           905
# mean                         NaN                 NaN           NaN
# std                          NaN                 NaN           NaN
# min                          NaN                 NaN           NaN
# 25%                          NaN                 NaN           NaN
# 50%                          NaN                 NaN           NaN
# 75%                          NaN                 NaN           NaN
# max                          NaN                 NaN           NaN
#
#        VersionControl           CheckInCode          ShipIt OtherPeoplesCode  \
# count           11571                 11204           11209            11202
# unique             10                     6               5                5
# top               Git  Multiple times a day  Somewhat agree   Somewhat agree
# freq             8235                  6164            3827             4507
# mean              NaN                   NaN             NaN              NaN
# std               NaN                   NaN             NaN              NaN
# min               NaN                   NaN             NaN              NaN
# 25%               NaN                   NaN             NaN              NaN
# 50%               NaN                   NaN             NaN              NaN
# 75%               NaN                   NaN             NaN              NaN
# max               NaN                   NaN             NaN              NaN
#
#        ProjectManagement  EnjoyDebugging InTheZone DifficultCommunication  \
# count              11122           11258     11101                  11210
# unique                 5               5         5                      5
# top             Disagree  Somewhat agree     Agree               Disagree
# freq                4844            3918      4741                   5814
# mean                 NaN             NaN       NaN                    NaN
# std                  NaN             NaN       NaN                    NaN
# min                  NaN             NaN       NaN                    NaN
# 25%                  NaN             NaN       NaN                    NaN
# 50%                  NaN             NaN       NaN                    NaN
# 75%                  NaN             NaN       NaN                    NaN
# max                  NaN             NaN       NaN                    NaN
#
#        CollaborateRemote                              MetricAssess  \
# count              11130                                      9625
# unique                 5                                      1445
# top       Somewhat agree  Customer satisfaction; On time/in budget
# freq                3404                                       360
# mean                 NaN                                       NaN
# std                  NaN                                       NaN
# min                  NaN                                       NaN
# 25%                  NaN                                       NaN
# 50%                  NaN                                       NaN
# 75%                  NaN                                       NaN
# max                  NaN                                       NaN
#
#        EquipmentSatisfiedMonitors EquipmentSatisfiedCPU EquipmentSatisfiedRAM  \
# count                       11130                 11127                 11133
# unique                          5                     5                     5
# top                     Satisfied             Satisfied             Satisfied
# freq                         4344                  4582                  4469
# mean                          NaN                   NaN                   NaN
# std                           NaN                   NaN                   NaN
# min                           NaN                   NaN                   NaN
# 25%                           NaN                   NaN                   NaN
# 50%                           NaN                   NaN                   NaN
# 75%                           NaN                   NaN                   NaN
# max                           NaN                   NaN                   NaN
#
#        EquipmentSatisfiedStorage EquipmentSatisfiedRW InfluenceInternet  \
# count                      11100                11110             11106
# unique                         5                    5                 5
# top                    Satisfied            Satisfied         Satisfied
# freq                        4558                 4633              4166
# mean                         NaN                  NaN               NaN
# std                          NaN                  NaN               NaN
# min                          NaN                  NaN               NaN
# 25%                          NaN                  NaN               NaN
# 50%                          NaN                  NaN               NaN
# 75%                          NaN                  NaN               NaN
# max                          NaN                  NaN               NaN
#
#        InfluenceWorkstation    InfluenceHardware     InfluenceServers  \
# count                  8262                 8262                 8239
# unique                    5                    5                    5
# top          Some influence  No influence at all  No influence at all
# freq                   2269                 4174                 3923
# mean                    NaN                  NaN                  NaN
# std                     NaN                  NaN                  NaN
# min                     NaN                  NaN                  NaN
# 25%                     NaN                  NaN                  NaN
# 50%                     NaN                  NaN                  NaN
# 75%                     NaN                  NaN                  NaN
# max                     NaN                  NaN                  NaN
#
#          InfluenceTechStack InfluenceDeptTech    InfluenceVizTools  \
# count                  8253              8243                 8244
# unique                    5                 5                    5
# top     No influence at all    Some influence  No influence at all
# freq                   3068              2291                 3833
# mean                    NaN               NaN                  NaN
# std                     NaN               NaN                  NaN
# min                     NaN               NaN                  NaN
# 25%                     NaN               NaN                  NaN
# 50%                     NaN               NaN                  NaN
# 75%                     NaN               NaN                  NaN
# max                     NaN               NaN                  NaN
#
#           InfluenceDatabase       InfluenceCloud InfluenceConsultants  \
# count                  8255                 8243                 8229
# unique                    5                    5                    5
# top     No influence at all  No influence at all  No influence at all
# freq                   3127                 3550                 4572
# mean                    NaN                  NaN                  NaN
# std                     NaN                  NaN                  NaN
# min                     NaN                  NaN                  NaN
# 25%                     NaN                  NaN                  NaN
# 50%                     NaN                  NaN                  NaN
# 75%                     NaN                  NaN                  NaN
# max                     NaN                  NaN                  NaN
#
#        InfluenceRecruitment InfluenceCommunication  \
# count                  8244                   8250
# unique                    5                      5
# top     No influence at all    No influence at all
# freq                   4950                   2554
# mean                    NaN                    NaN
# std                     NaN                    NaN
# min                     NaN                    NaN
# 25%                     NaN                    NaN
# 50%                     NaN                    NaN
# 75%                     NaN                    NaN
# max                     NaN                    NaN
#
#                                    StackOverflowDescribes  \
# count                                               13556
# unique                                                  5
# top     I have a login for Stack Overflow, but haven't...
# freq                                                 6994
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         StackOverflowSatisfaction StackOverflowDevices  \
# count                13452.000000                12946
# unique                        NaN                   37
# top                           NaN              Desktop
# freq                          NaN                 6121
# mean                     8.357865                  NaN
# std                      1.405546                  NaN
# min                      0.000000                  NaN
# 25%                      8.000000                  NaN
# 50%                      8.000000                  NaN
# 75%                      9.000000                  NaN
# max                     10.000000                  NaN
#
#        StackOverflowFoundAnswer StackOverflowCopiedCode  \
# count                     12691                   12577
# unique                        5                       5
# top     At least once each week           Once or twice
# freq                       4854                    3944
# mean                        NaN                     NaN
# std                         NaN                     NaN
# min                         NaN                     NaN
# 25%                         NaN                     NaN
# 50%                         NaN                     NaN
# 75%                         NaN                     NaN
# max                         NaN                     NaN
#
#        StackOverflowJobListing StackOverflowCompanyPage  \
# count                    12425                    12411
# unique                       5                        5
# top        Haven't done at all      Haven't done at all
# freq                      7576                     9884
# mean                       NaN                      NaN
# std                        NaN                      NaN
# min                        NaN                      NaN
# 25%                        NaN                      NaN
# 50%                        NaN                      NaN
# 75%                        NaN                      NaN
# max                        NaN                      NaN
#
#        StackOverflowJobSearch StackOverflowNewQuestion  StackOverflowAnswer  \
# count                   12407                    12472                12445
# unique                      5                        5                    5
# top       Haven't done at all      Haven't done at all  Haven't done at all
# freq                     9106                     8164                 7356
# mean                      NaN                      NaN                  NaN
# std                       NaN                      NaN                  NaN
# min                       NaN                      NaN                  NaN
# 25%                       NaN                      NaN                  NaN
# 50%                       NaN                      NaN                  NaN
# 75%                       NaN                      NaN                  NaN
# max                       NaN                      NaN                  NaN
#
#        StackOverflowMetaChat StackOverflowAdsRelevant  \
# count                  12414                    11527
# unique                     5                        5
# top      Haven't done at all           Somewhat agree
# freq                   10601                     5082
# mean                     NaN                      NaN
# std                      NaN                      NaN
# min                      NaN                      NaN
# 25%                      NaN                      NaN
# 50%                      NaN                      NaN
# 75%                      NaN                      NaN
# max                      NaN                      NaN
#
#        StackOverflowAdsDistracting StackOverflowModeration  \
# count                        11841                   11336
# unique                           5                       5
# top                       Disagree                Disagree
# freq                          6645                    6730
# mean                           NaN                     NaN
# std                            NaN                     NaN
# min                            NaN                     NaN
# 25%                            NaN                     NaN
# 50%                            NaN                     NaN
# 75%                            NaN                     NaN
# max                            NaN                     NaN
#
#        StackOverflowCommunity StackOverflowHelpful StackOverflowBetter  \
# count                   12064                12542               12462
# unique                      5                    5                   5
# top            Somewhat agree                Agree      Strongly agree
# freq                     3974                 6300                5412
# mean                      NaN                  NaN                 NaN
# std                       NaN                  NaN                 NaN
# min                       NaN                  NaN                 NaN
# 25%                       NaN                  NaN                 NaN
# 50%                       NaN                  NaN                 NaN
# 75%                       NaN                  NaN                 NaN
# max                       NaN                  NaN                 NaN
#
#        StackOverflowWhatDo StackOverflowMakeMoney Gender  \
# count                12385                  11668  12910
# unique                   5                      5     20
# top         Somewhat agree               Disagree   Male
# freq                  3308                   6902  11664
# mean                   NaN                    NaN    NaN
# std                    NaN                    NaN    NaN
# min                    NaN                    NaN    NaN
# 25%                    NaN                    NaN    NaN
# 50%                    NaN                    NaN    NaN
# 75%                    NaN                    NaN    NaN
# max                    NaN                    NaN    NaN
#
#        HighestEducationParents                          Race      SurveyLong  \
# count                    12853                         12218           12803
# unique                      10                            59               5
# top        A bachelor's degree  White or of European descent  Somewhat agree
# freq                      3671                          8954            4140
# mean                       NaN                           NaN             NaN
# std                        NaN                           NaN             NaN
# min                        NaN                           NaN             NaN
# 25%                        NaN                           NaN             NaN
# 50%                        NaN                           NaN             NaN
# 75%                        NaN                           NaN             NaN
# max                        NaN                           NaN             NaN
#
#        QuestionsInteresting QuestionsConfusing InterestedAnswers  \
# count                 12736              12706             12760
# unique                    5                  5                 5
# top                   Agree           Disagree             Agree
# freq                   5753               8017              5482
# mean                    NaN                NaN               NaN
# std                     NaN                NaN               NaN
# min                     NaN                NaN               NaN
# 25%                     NaN                NaN               NaN
# 50%                     NaN                NaN               NaN
# 75%                     NaN                NaN               NaN
# max                     NaN                NaN               NaN
#
#                Salary  ExpectedSalary
# count     5009.000000      818.000000
# unique            NaN             NaN
# top               NaN             NaN
# freq              NaN             NaN
# mean     58341.398571    32231.521687
# std      40753.384986    28543.877274
# min          0.000000        0.000000
# 25%      27956.989247     4716.459735
# 50%      51612.903226    29784.946237
# 75%      83333.333333    50000.000000
# max     195000.000000   120000.000000

# %%
df.dtypes
# Out:
# Respondent                            int64
# Professional                         object
# ProgramHobby                         object
# Country                              object
# University                           object
# EmploymentStatus                     object
# FormalEducation                      object
# MajorUndergrad                       object
# HomeRemote                           object
# CompanySize                          object
# CompanyType                          object
# YearsProgram                         object
# YearsCodedJob                        object
# YearsCodedJobPast                    object
# DeveloperType                        object
# WebDeveloperType                     object
# MobileDeveloperType                  object
# NonDeveloperType                     object
# CareerSatisfaction                  float64
# JobSatisfaction                     float64
# ExCoderReturn                        object
# ExCoderNotForMe                      object
# ExCoderBalance                       object
# ExCoder10Years                       object
# ExCoderBelonged                      object
# ExCoderSkills                        object
# ExCoderWillNotCode                   object
# ExCoderActive                        object
# PronounceGIF                         object
# ProblemSolving                       object
# BuildingThings                       object
# LearningNewTech                      object
# BoringDetails                        object
# JobSecurity                          object
# DiversityImportant                   object
# AnnoyingUI                           object
# FriendsDevelopers                    object
# RightWrongWay                        object
# UnderstandComputers                  object
# SeriousWork                          object
# InvestTimeTools                      object
# WorkPayCare                          object
# KinshipDevelopers                    object
# ChallengeMyself                      object
# CompetePeers                         object
# ChangeWorld                          object
# JobSeekingStatus                     object
# HoursPerWeek                        float64
# LastNewJob                           object
# AssessJobIndustry                    object
# AssessJobRole                        object
# AssessJobExp                         object
# AssessJobDept                        object
# AssessJobTech                        object
# AssessJobProjects                    object
# AssessJobCompensation                object
# AssessJobOffice                      object
# AssessJobCommute                     object
# AssessJobRemote                      object
# AssessJobLeaders                     object
# AssessJobProfDevel                   object
# AssessJobDiversity                   object
# AssessJobProduct                     object
# AssessJobFinances                    object
# ImportantBenefits                    object
# ClickyKeys                           object
# JobProfile                           object
# ResumePrompted                       object
# LearnedHiring                        object
# ImportantHiringAlgorithms            object
# ImportantHiringTechExp               object
# ImportantHiringCommunication         object
# ImportantHiringOpenSource            object
# ImportantHiringPMExp                 object
# ImportantHiringCompanies             object
# ImportantHiringTitles                object
# ImportantHiringEducation             object
# ImportantHiringRep                   object
# ImportantHiringGettingThingsDone     object
# Currency                             object
# Overpaid                             object
# TabsSpaces                           object
# EducationImportant                   object
# EducationTypes                       object
# SelfTaughtTypes                      object
# TimeAfterBootcamp                    object
# CousinEducation                      object
# WorkStart                            object
# HaveWorkedLanguage                   object
# WantWorkLanguage                     object
# HaveWorkedFramework                  object
# WantWorkFramework                    object
# HaveWorkedDatabase                   object
# WantWorkDatabase                     object
# HaveWorkedPlatform                   object
# WantWorkPlatform                     object
# IDE                                  object
# AuditoryEnvironment                  object
# Methodology                          object
# VersionControl                       object
# CheckInCode                          object
# ShipIt                               object
# OtherPeoplesCode                     object
# ProjectManagement                    object
# EnjoyDebugging                       object
# InTheZone                            object
# DifficultCommunication               object
# CollaborateRemote                    object
# MetricAssess                         object
# EquipmentSatisfiedMonitors           object
# EquipmentSatisfiedCPU                object
# EquipmentSatisfiedRAM                object
# EquipmentSatisfiedStorage            object
# EquipmentSatisfiedRW                 object
# InfluenceInternet                    object
# InfluenceWorkstation                 object
# InfluenceHardware                    object
# InfluenceServers                     object
# InfluenceTechStack                   object
# InfluenceDeptTech                    object
# InfluenceVizTools                    object
# InfluenceDatabase                    object
# InfluenceCloud                       object
# InfluenceConsultants                 object
# InfluenceRecruitment                 object
# InfluenceCommunication               object
# StackOverflowDescribes               object
# StackOverflowSatisfaction           float64
# StackOverflowDevices                 object
# StackOverflowFoundAnswer             object
# StackOverflowCopiedCode              object
# StackOverflowJobListing              object
# StackOverflowCompanyPage             object
# StackOverflowJobSearch               object
# StackOverflowNewQuestion             object
# StackOverflowAnswer                  object
# StackOverflowMetaChat                object
# StackOverflowAdsRelevant             object
# StackOverflowAdsDistracting          object
# StackOverflowModeration              object
# StackOverflowCommunity               object
# StackOverflowHelpful                 object
# StackOverflowBetter                  object
# StackOverflowWhatDo                  object
# StackOverflowMakeMoney               object
# Gender                               object
# HighestEducationParents              object
# Race                                 object
# SurveyLong                           object
# QuestionsInteresting                 object
# QuestionsConfusing                   object
# InterestedAnswers                    object
# Salary                              float64
# ExpectedSalary                      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Respondent                              0
# Professional                            0
# ProgramHobby                            0
# Country                                 0
# University                              0
# EmploymentStatus                        0
# FormalEducation                         0
# MajorUndergrad                       3203
# HomeRemote                           2631
# CompanySize                          4449
# CompanyType                          4493
# YearsProgram                           97
# YearsCodedJob                        3711
# YearsCodedJobPast                   18753
# DeveloperType                        5330
# WebDeveloperType                    14816
# MobileDeveloperType                 18546
# NonDeveloperType                    17414
# CareerSatisfaction                   3000
# JobSatisfaction                      3849
# ExCoderReturn                       18767
# ExCoderNotForMe                     18770
# ExCoderBalance                      18767
# ExCoder10Years                      18766
# ExCoderBelonged                     18767
# ExCoderSkills                       18766
# ExCoderWillNotCode                  18770
# ExCoderActive                       18767
# PronounceGIF                          162
# ProblemSolving                       6882
# BuildingThings                       6901
# LearningNewTech                      6886
# BoringDetails                        6912
# JobSecurity                          6904
# DiversityImportant                   7023
# AnnoyingUI                           6962
# FriendsDevelopers                    6959
# RightWrongWay                        6990
# UnderstandComputers                  6967
# SeriousWork                          6970
# InvestTimeTools                      7043
# WorkPayCare                          7015
# KinshipDevelopers                    7122
# ChallengeMyself                      7013
# CompetePeers                         7068
# ChangeWorld                          7025
# JobSeekingStatus                     6250
# HoursPerWeek                        11381
# LastNewJob                           6524
# AssessJobIndustry                   10701
# AssessJobRole                       10699
# AssessJobExp                        10704
# AssessJobDept                       10712
# AssessJobTech                       10682
# AssessJobProjects                   10690
# AssessJobCompensation               10695
# AssessJobOffice                     10766
# AssessJobCommute                    10771
# AssessJobRemote                     10751
# AssessJobLeaders                    10772
# AssessJobProfDevel                  10761
# AssessJobDiversity                  10778
# AssessJobProduct                    10768
# AssessJobFinances                   10751
# ImportantBenefits                    7532
# ClickyKeys                           3744
# JobProfile                           9912
# ResumePrompted                      10398
# LearnedHiring                        9919
# ImportantHiringAlgorithms            8212
# ImportantHiringTechExp               8208
# ImportantHiringCommunication         8223
# ImportantHiringOpenSource            8238
# ImportantHiringPMExp                 8233
# ImportantHiringCompanies             8251
# ImportantHiringTitles                8243
# ImportantHiringEducation             8219
# ImportantHiringRep                   8224
# ImportantHiringGettingThingsDone     8253
# Currency                            11070
# Overpaid                            13918
# TabsSpaces                           4797
# EducationImportant                  10037
# EducationTypes                       7637
# SelfTaughtTypes                      8929
# TimeAfterBootcamp                   18220
# CousinEducation                     12196
# WorkStart                            5579
# HaveWorkedLanguage                   5576
# WantWorkLanguage                     6579
# HaveWorkedFramework                 11808
# WantWorkFramework                   10603
# HaveWorkedDatabase                   8310
# WantWorkDatabase                     9943
# HaveWorkedPlatform                   8522
# WantWorkPlatform                     8944
# IDE                                  5905
# AuditoryEnvironment                  5651
# Methodology                          9515
# VersionControl                       7531
# CheckInCode                          7898
# ShipIt                               7893
# OtherPeoplesCode                     7900
# ProjectManagement                    7980
# EnjoyDebugging                       7844
# InTheZone                            8001
# DifficultCommunication               7892
# CollaborateRemote                    7972
# MetricAssess                         9477
# EquipmentSatisfiedMonitors           7972
# EquipmentSatisfiedCPU                7975
# EquipmentSatisfiedRAM                7969
# EquipmentSatisfiedStorage            8002
# EquipmentSatisfiedRW                 7992
# InfluenceInternet                    7996
# InfluenceWorkstation                10840
# InfluenceHardware                   10840
# InfluenceServers                    10863
# InfluenceTechStack                  10849
# InfluenceDeptTech                   10859
# InfluenceVizTools                   10858
# InfluenceDatabase                   10847
# InfluenceCloud                      10859
# InfluenceConsultants                10873
# InfluenceRecruitment                10858
# InfluenceCommunication              10852
# StackOverflowDescribes               5546
# StackOverflowSatisfaction            5650
# StackOverflowDevices                 6156
# StackOverflowFoundAnswer             6411
# StackOverflowCopiedCode              6525
# StackOverflowJobListing              6677
# StackOverflowCompanyPage             6691
# StackOverflowJobSearch               6695
# StackOverflowNewQuestion             6630
# StackOverflowAnswer                  6657
# StackOverflowMetaChat                6688
# StackOverflowAdsRelevant             7575
# StackOverflowAdsDistracting          7261
# StackOverflowModeration              7766
# StackOverflowCommunity               7038
# StackOverflowHelpful                 6560
# StackOverflowBetter                  6640
# StackOverflowWhatDo                  6717
# StackOverflowMakeMoney               7434
# Gender                               6192
# HighestEducationParents              6249
# Race                                 6884
# SurveyLong                           6299
# QuestionsInteresting                 6366
# QuestionsConfusing                   6396
# InterestedAnswers                    6342
# Salary                              14093
# ExpectedSalary                      18284
# dtype: int64

# %%
count = 0
for col in df.columns:
    if not df[col].isnull().any():
        count += 1
        print(col)
print(count)
# Out:
# Respondent
# Professional
# ProgramHobby
# Country
# University
# EmploymentStatus
# FormalEducation
# 7

# %% [markdown]
# Has null values, but no mixed type.

# %%
no_nulls = set([col for col in df.columns if not df[col].isnull().any()]) #Provide a set of columns with 0 missing values.

display.HTML(t.no_null_cols(no_nulls))
# Out:
# Nice job that looks right!
# <img src="https://bit.ly/2K9X0gD">

# %% [markdown]
# ### Question 3
#
# **3.** Which columns have the most missing values?  Provide a set of column names that have more than 75% if their values missing.

# %%
count = 0
for col in df.columns:
    if df[col].isnull().sum()/len(df[col]) > 0.75:
        count += 1
        print(col)
print(count)
# Out:
# YearsCodedJobPast
# WebDeveloperType
# MobileDeveloperType
# NonDeveloperType
# ExCoderReturn
# ExCoderNotForMe
# ExCoderBalance
# ExCoder10Years
# ExCoderBelonged
# ExCoderSkills
# ExCoderWillNotCode
# ExCoderActive
# TimeAfterBootcamp
# ExpectedSalary
# 14

# %%
most_missing_cols = set([col for col in df.columns if df[col].isnull().sum()/len(df[col]) > 0.75])#Provide a set of columns with more than 75% of the values missing

t.most_missing_cols(most_missing_cols)
# Out:
# Nice job that looks right!

# %% [markdown]
# ### Question 4
#
# **4.** Provide a pandas series of the different **Professional** status values in the dataset along with the count of the number of individuals with each status.  Store this pandas series in **status_vals**.  If you are correct, you should see a bar chart of the proportion of individuals in each status.

# %%
set(df['Professional'])
# Out:
# {'None of these',
#  'Professional developer',
#  'Professional non-developer who sometimes writes code',
#  'Student',
#  'Used to be a professional developer'}

# %%
df['Professional'].value_counts()
# Out:
# Professional developer                                  13774
# Student                                                  2821
# Professional non-developer who sometimes writes code     1782
# None of these                                             368
# Used to be a professional developer                       357
# Name: Professional, dtype: int64

# %%
status_vals = df['Professional'].value_counts()#Provide a pandas series of the counts for each Professional status

# The below should be a bar chart of the proportion of individuals in each professional category if your status_vals
# is set up correctly.

(status_vals/df.shape[0]).plot(kind="bar");
plt.title("What kind of developer are you?");

# %% [markdown]
# ### Question 5
#
# **5.** Provide a pandas series of the different **FormalEducation** status values in the dataset along with the count of how many individuals received that formal education.  Store this pandas series in **ed_vals**.  If you are correct, you should see a bar chart of the proportion of individuals in each status.

# %%
df['FormalEducation'].value_counts()
# Out:
# Bachelor's degree                                                    8099
# Master's degree                                                      4143
# Some college/university study without earning a bachelor's degree    2869
# Secondary school                                                     2227
# Doctoral degree                                                       551
# I prefer not to answer                                                409
# Primary/elementary school                                             404
# Professional degree                                                   255
# I never completed any formal education                                145
# Name: FormalEducation, dtype: int64

# %%
ed_vals = df['FormalEducation'].value_counts() #Provide a pandas series of the counts for each FormalEducation status

# The below should be a bar chart of the proportion of individuals in your ed_vals
# if it is set up correctly.

(ed_vals/df.shape[0]).plot(kind="bar");
plt.title("Formal Education");

# %% [markdown]
# ### Question 6
#
# **6.** Provide a pandas series of the different **Country** values in the dataset along with the count of how many individuals are from each country.  Store this pandas series in **count_vals**.  If you are correct, you should see a bar chart of the proportion of individuals in each country.

# %%
df['Country'].value_counts()
# Out:
# United States                     4364
# India                             1557
# United Kingdom                    1424
# Germany                           1337
# Canada                             874
# Poland                             694
# France                             522
# Australia                          399
# Netherlands                        373
# Israel                             338
# Russian Federation                 330
# Spain                              312
# Italy                              304
# Sweden                             267
# Brazil                             259
# Romania                            251
# Switzerland                        242
# Slovenia                           190
# Austria                            190
# Iran                               174
# Czech Republic                     167
# Pakistan                           160
# Ukraine                            148
# Turkey                             146
# Belgium                            138
# Ireland                            134
# Finland                            132
# Greece                             129
# Hungary                            122
# China                              119
# South Africa                       118
# Mexico                             118
# Denmark                            112
# Serbia                             111
# Philippines                        111
# Indonesia                          108
# New Zealand                        108
# Japan                              107
# Bulgaria                           107
# Norway                             100
# Argentina                           99
# Portugal                            95
# Croatia                             80
# Malaysia                            75
# Bangladesh                          74
# Slovak Republic                     72
# South Korea                         69
# Singapore                           68
# Lithuania                           64
# Sri Lanka                           59
# Hong Kong                           59
# I prefer not to say                 57
# Vietnam                             57
# Colombia                            55
# Thailand                            54
# Egypt                               50
# Nepal                               49
# Taiwan                              48
# United Arab Emirates                45
# Nigeria                             44
# Latvia                              44
# Chile                               43
# Estonia                             40
# Bosnia-Herzegovina                  35
# Dominican Republic                  33
# Uruguay                             32
# Belarus                             31
# Albania                             30
# Armenia                             28
# Kenya                               24
# Peru                                23
# Macedonia                           22
# Tunisia                             22
# Moldavia                            20
# Morocco                             20
# Georgia                             19
# Costa Rica                          17
# Kazakhstan                          16
# Algeria                             16
# Venezuela                           16
# Ghana                               16
# Lebanon                             15
# Guatemala                           15
# Myanmar                             14
# Ecuador                             14
# Saudi Arabia                        14
# Jordan                              13
# Afghanistan                         13
# Malta                               13
# Paraguay                            13
# Ethiopia                            12
# Mongolia                            12
# Azerbaidjan                         11
# El Salvador                         10
# Cuba                                10
# Luxembourg                          10
# Iceland                              9
# Uganda                               9
# Nicaragua                            8
# Trinidad and Tobago                  7
# Uzbekistan                           7
# Aland Islands                        7
# Cambodia                             6
# Bolivia                              6
# Kuwait                               6
# Jamaica                              6
# Cyprus                               6
# Tanzania                             5
# Honduras                             5
# Andorra                              4
# Liechtenstein                        4
# Zimbabwe                             4
# Rwanda                               4
# Cameroon                             4
# Puerto Rico                          4
# Mauritius                            4
# Panama                               4
# Botswana                             3
# Oman                                 3
# Syria                                3
# Antarctica                           3
# Haiti                                3
# Somalia                              3
# North Korea                          3
# Iraq                                 3
# Madagascar                           3
# Namibia                              3
# New Caledonia (French)               2
# Netherlands Antilles                 2
# Reunion (French)                     2
# Kyrgyzstan                           2
# Mozambique                           2
# Zambia                               2
# Bouvet Island                        2
# Bermuda                              2
# Guyana                               2
# Bahrain                              2
# Bahamas                              1
# S. Georgia & S. Sandwich Isls.       1
# Anguilla                             1
# Libya                                1
# American Samoa                       1
# Fiji                                 1
# Virgin Islands (USA)                 1
# Laos                                 1
# Lesotho                              1
# Malawi                               1
# Virgin Islands (British)             1
# Gabon                                1
# Sudan                                1
# Montenegro                           1
# Togo                                 1
# Cayman Islands                       1
# Tadjikistan                          1
# Gibraltar                            1
# Cape Verde                           1
# Senegal                              1
# Brunei Darussalam                    1
# Bhutan                               1
# Angola                               1
# Qatar                                1
# Burkina Faso                         1
# Vatican City State                   1
# Ivory Coast (Cote D'Ivoire)          1
# Zaire                                1
# Name: Country, dtype: int64

# %%
count_vals = df['Country'].value_counts() #Provide a pandas series of the counts for each Country

# The below should be a bar chart of the proportion of the top 10 countries for the
# individuals in your count_vals if it is set up correctly.

(count_vals[:10]/df.shape[0]).plot(kind="bar");
plt.title("Country");

# %% [markdown]
# Feel free to explore the dataset further to gain additional familiarity with the columns and rows in the dataset.  You will be working pretty closely with this dataset throughout this lesson.
