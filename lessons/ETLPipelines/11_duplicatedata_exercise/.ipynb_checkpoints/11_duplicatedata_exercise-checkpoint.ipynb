# %% [markdown]
# # Duplicate Data
#
# A data set might have duplicate data: in other words, the same record is represented multiple times. Sometimes, it's easy to find and eliminate duplicate data like when two records are exactly the same. At other times, like what was discussed in the video, duplicate data is hard to spot.
#
# # Exercise 1
#
# From the World Bank GDP data, count the number of countries that have had a project totalamt greater than 1 billion dollars (1,000,000,000). To get the count, you'll have to remove duplicate data rows.

# %%
projects.head().T
# Out:
#                                                                           0  \
# id                                                                  P162228
# regionname                                                            Other
# countryname                                                           World
# prodline                                                                 RE
# lendinginstr                                   Investment Project Financing
# lendinginstrtype                                                         IN
# envassesmentcategorycode                                                  C
# supplementprojectflg                                                      N
# productlinetype                                                           L
# projectstatusdisplay                                                 Active
# status                                                               Active
# project_name               Creating a Trade in Value-Added Database for ...
# boardapprovaldate                                 2018-06-28 00:00:00+00:00
# board_approval_month                                                   June
# closingdate                                                             NaN
# lendprojectcost                                                     500,000
# ibrdcommamt                                                               0
# idacommamt                                                                0
# totalamt                                                                  0
# grantamt                                                            500,000
# borrower                                                                NaN
# impagency                                                               NaN
# url                           http://projects.worldbank.org/P162228?lang=en
# projectdoc                                                              NaN
# majorsector_percent                                                     NaN
# sector1                                                                !$!0
# sector2                                                                 NaN
# sector3                                                                 NaN
# sector4                                                                 NaN
# sector5                                                                 NaN
# sector                                                                  NaN
# mjsector1                                                               NaN
# mjsector2                                                               NaN
# mjsector3                                                               NaN
# mjsector4                                                               NaN
# mjsector5                                                               NaN
# mjsector                                                                NaN
# theme1                                                                 !$!0
# theme2                                                                  NaN
# theme3                                                                  NaN
# theme4                                                                  NaN
# theme5                                                                  NaN
# theme                                                                   NaN
# goal                                                                    NaN
# financier                                                               NaN
# mjtheme1name                                                            NaN
# mjtheme2name                                                            NaN
# mjtheme3name                                                            NaN
# mjtheme4name                                                            NaN
# mjtheme5name                                                            NaN
# location                                                                NaN
# GeoLocID                                                                NaN
# GeoLocName                                                              NaN
# Latitude                                                                NaN
# Longitude                                                               NaN
# Country                                                                 NaN
#
#                                                                       1  \
# id                                                              P163962
# regionname                                                       Africa
# countryname                            Democratic Republic of the Congo
# prodline                                                             PE
# lendinginstr                               Investment Project Financing
# lendinginstrtype                                                     IN
# envassesmentcategorycode                                              B
# supplementprojectflg                                                  N
# productlinetype                                                       L
# projectstatusdisplay                                             Active
# status                                                           Active
# project_name                               Productive Inclusion Project
# boardapprovaldate                             2018-06-28 00:00:00+00:00
# board_approval_month                                               June
# closingdate                                        2023-12-31T00:00:00Z
# lendprojectcost                                             200,000,000
# ibrdcommamt                                                           0
# idacommamt                                                  200,000,000
# totalamt                                                      200000000
# grantamt                                                              0
# borrower                                                            NaN
# impagency                                                           NaN
# url                       http://projects.worldbank.org/P163962?lang=en
# projectdoc                                                          NaN
# majorsector_percent                                                 NaN
# sector1                                                            !$!0
# sector2                                                             NaN
# sector3                                                             NaN
# sector4                                                             NaN
# sector5                                                             NaN
# sector                                                              NaN
# mjsector1                                                           NaN
# mjsector2                                                           NaN
# mjsector3                                                           NaN
# mjsector4                                                           NaN
# mjsector5                                                           NaN
# mjsector                                                            NaN
# theme1                                                             !$!0
# theme2                                                              NaN
# theme3                                                              NaN
# theme4                                                              NaN
# theme5                                                              NaN
# theme                                                               NaN
# goal                                                                NaN
# financier                                                           NaN
# mjtheme1name                                                        NaN
# mjtheme2name                                                        NaN
# mjtheme3name                                                        NaN
# mjtheme4name                                                        NaN
# mjtheme5name                                                        NaN
# location                                                            NaN
# GeoLocID                                                            NaN
# GeoLocName                                                          NaN
# Latitude                                                            NaN
# Longitude                                                           NaN
# Country                                                             NaN
#
#                                                                           2  \
# id                                                                  P167672
# regionname                                                       South Asia
# countryname                                 People's Republic of Bangladesh
# prodline                                                                 PE
# lendinginstr                                   Investment Project Financing
# lendinginstrtype                                                         IN
# envassesmentcategorycode                                                NaN
# supplementprojectflg                                                      Y
# productlinetype                                                           L
# projectstatusdisplay                                                 Active
# status                                                               Active
# project_name              Additional Financing for Health Sector Support...
# boardapprovaldate                                 2018-06-28 00:00:00+00:00
# board_approval_month                                                   June
# closingdate                                                             NaN
# lendprojectcost                                                  50,000,000
# ibrdcommamt                                                               0
# idacommamt                                                       58,330,000
# totalamt                                                           58330000
# grantamt                                                                  0
# borrower                                                                NaN
# impagency                                                               NaN
# url                           http://projects.worldbank.org/P167672?lang=en
# projectdoc                                                              NaN
# majorsector_percent                                                     NaN
# sector1                                                                !$!0
# sector2                                                                 NaN
# sector3                                                                 NaN
# sector4                                                                 NaN
# sector5                                                                 NaN
# sector                                                                  NaN
# mjsector1                                                               NaN
# mjsector2                                                               NaN
# mjsector3                                                               NaN
# mjsector4                                                               NaN
# mjsector5                                                               NaN
# mjsector                                                                NaN
# theme1                                                                 !$!0
# theme2                                                                  NaN
# theme3                                                                  NaN
# theme4                                                                  NaN
# theme5                                                                  NaN
# theme                                                                   NaN
# goal                                                                    NaN
# financier                                                               NaN
# mjtheme1name                                                            NaN
# mjtheme2name                                                            NaN
# mjtheme3name                                                            NaN
# mjtheme4name                                                            NaN
# mjtheme5name                                                            NaN
# location                                                                NaN
# GeoLocID                                                                NaN
# GeoLocName                                                              NaN
# Latitude                                                                NaN
# Longitude                                                               NaN
# Country                                                                 NaN
#
#                                                                           3  \
# id                                                                  P158768
# regionname                                                       South Asia
# countryname                                Islamic  Republic of Afghanistan
# prodline                                                                 PE
# lendinginstr                                   Investment Project Financing
# lendinginstrtype                                                         IN
# envassesmentcategorycode                                                  A
# supplementprojectflg                                                      N
# productlinetype                                                           L
# projectstatusdisplay                                                 Active
# status                                                               Active
# project_name              Public-Private Partnerships and Public Investm...
# boardapprovaldate                                 2018-06-27 00:00:00+00:00
# board_approval_month                                                   June
# closingdate                                            2023-06-28T00:00:00Z
# lendprojectcost                                                  50,000,000
# ibrdcommamt                                                               0
# idacommamt                                                       20,000,000
# totalamt                                                           20000000
# grantamt                                                                  0
# borrower                                                               IIST
# impagency                                                              IIST
# url                           http://projects.worldbank.org/P158768?lang=en
# projectdoc                                                              NaN
# majorsector_percent                                                     NaN
# sector1                                                                !$!0
# sector2                                                                 NaN
# sector3                                                                 NaN
# sector4                                                                 NaN
# sector5                                                                 NaN
# sector                                                                  NaN
# mjsector1                                                               NaN
# mjsector2                                                               NaN
# mjsector3                                                               NaN
# mjsector4                                                               NaN
# mjsector5                                                               NaN
# mjsector                                                                NaN
# theme1                                                                 !$!0
# theme2                                                                  NaN
# theme3                                                                  NaN
# theme4                                                                  NaN
# theme5                                                                  NaN
# theme                                                                   NaN
# goal                                                                    NaN
# financier                                                               NaN
# mjtheme1name                                                            NaN
# mjtheme2name                                                            NaN
# mjtheme3name                                                            NaN
# mjtheme4name                                                            NaN
# mjtheme5name                                                            NaN
# location                                                                NaN
# GeoLocID                                                                NaN
# GeoLocName                                                              NaN
# Latitude                                                                NaN
# Longitude                                                               NaN
# Country                                                                 NaN
#
#                                                                           4
# id                                                                  P161364
# regionname                                                           Africa
# countryname                                     Federal Republic of Nigeria
# prodline                                                                 PE
# lendinginstr                                   Investment Project Financing
# lendinginstrtype                                                         IN
# envassesmentcategorycode                                                  B
# supplementprojectflg                                                      N
# productlinetype                                                           L
# projectstatusdisplay                                                 Active
# status                                                               Active
# project_name                                      Nigeria For Women Project
# boardapprovaldate                                 2018-06-27 00:00:00+00:00
# board_approval_month                                                   June
# closingdate                                            2023-05-31T00:00:00Z
# lendprojectcost                                                 100,000,000
# ibrdcommamt                                                               0
# idacommamt                                                      100,000,000
# totalamt                                                          100000000
# grantamt                                                                  0
# borrower                                                                NaN
# impagency                                                               NaN
# url                           http://projects.worldbank.org/P161364?lang=en
# projectdoc                                                              NaN
# majorsector_percent                                                     NaN
# sector1                                         Social Protection!$!63!$!SA
# sector2                        Other Industry; Trade and Services!$!25!$!YZ
# sector3                    Other Agriculture; Fishing and Forestry!$!2!$!AZ
# sector4                               Other Public Administration!$!10!$!BZ
# sector5                                                                 NaN
# sector                    Social Protection;Social Protection;Other Indu...
# mjsector1                                                               NaN
# mjsector2                                                               NaN
# mjsector3                                                               NaN
# mjsector4                                                               NaN
# mjsector5                                                               NaN
# mjsector                  Social Protection;Social Protection;Industry; ...
# theme1                                                                 !$!0
# theme2                                                                  NaN
# theme3                                                                  NaN
# theme4                                                                  NaN
# theme5                                                                  NaN
# theme                                                                   NaN
# goal                                                                    NaN
# financier                                                               NaN
# mjtheme1name                                                            NaN
# mjtheme2name                                                            NaN
# mjtheme3name                                                            NaN
# mjtheme4name                                                            NaN
# mjtheme5name                                                            NaN
# location                  0002327546!$!Ogun State!$!7!$!3.58333!$!NG;000...
# GeoLocID                  0002327546;0002328925;0002565340;0002565343;00...
# GeoLocName                Ogun State;Niger State;Abia State;Edo;Kebbi St...
# Latitude                                            7;10;5.41667;6.5;11.5;8
# Longitude                                            3.58333;6;7.5;6;4;10.5
# Country                                                   NG;NG;NG;NG;NG;NG

# %%
import pandas as pd

# read in the projects data set and do some basic wrangling 
projects = pd.read_csv('../data/projects_data.csv', dtype=str)
projects.drop('Unnamed: 56', axis=1, inplace=True)
projects['totalamt'] = pd.to_numeric(projects['totalamt'].str.replace(',', ''))
projects['countryname'] = projects['countryname'].str.split(';', expand=True)[0]
projects['boardapprovaldate'] = pd.to_datetime(projects['boardapprovaldate'])

# TODO: filter the data frame for projects over 1 billion dollars

# TODO: count the number of unique countries in the results
projects[projects['totalamt']>1000000000]['countryname'].nunique()
# Out:
# 17

# %% [markdown]
# # Exercise 2 (challenge)
#
# This exercise is more challenging. The projects data set contains data about Yugoslavia, which was an Eastern European country until 1992. Yugoslavia eventually broke up into 7 countries: Bosnia and Herzegovina, Croatia, Kosovo, Macedonia, Montenegro, Serbia, and Slovenia.
#
# But the projects dataset has some ambiguity in how it treats Yugoslavia and the 7 countries that came from Yugoslavia. Your task is to find Yugoslavia projects that are probably represented multiple times in the data set.

# %%
# TODO: output all projects for the 'Socialist Federal Republic of Yugoslavia'
# HINT: You can use the exact country name or use the pandas str.contains() method to search for Yugoslavia

# %%
for name in set(projects['countryname']):
    if "Yugoslavia" in name:
        print(name)
# Out:
# Socialist Federal Republic of Yugoslavia

# %%
set(projects['countryname'])
# Out:
# {'Africa',
#  'American Samoa',
#  'Andean Countries',
#  'Antigua and Barbuda',
#  'Arab Republic of Egypt',
#  'Aral Sea',
#  'Argentine Republic',
#  'Asia',
#  'Barbados',
#  'Belize',
#  'Bosnia and Herzegovina',
#  'Burkina Faso',
#  'Caribbean',
#  'Caucasus',
#  'Central Africa',
#  'Central African Republic',
#  'Central America',
#  'Central Asia',
#  'Co-operative Republic of Guyana',
#  'Commonwealth of Australia',
#  'Commonwealth of Dominica',
#  'Commonwealth of The Bahamas',
#  'Czech Republic',
#  'Democratic Republic of Sao Tome and Prin',
#  'Democratic Republic of Timor-Leste',
#  'Democratic Republic of the Congo',
#  'Democratic Socialist Republic of Sri Lan',
#  'Dominican Republic',
#  'EU Accession Countries',
#  'East Asia and Pacific',
#  'Eastern Africa',
#  'Europe and Central Asia',
#  'Federal Democratic Republic of Ethiopia',
#  'Federal Republic of Nigeria',
#  'Federated States of Micronesia',
#  'Federative Republic of Brazil',
#  'French Republic',
#  'Gabonese Republic',
#  'Georgia',
#  'Grand Duchy of Luxembourg',
#  'Grenada',
#  'Hashemite Kingdom of Jordan',
#  'Hellenic Republic',
#  'Hungary',
#  'Ireland',
#  'Islamic  Republic of Afghanistan',
#  'Islamic Republic of Iran',
#  'Islamic Republic of Mauritania',
#  'Islamic Republic of Pakistan',
#  'Italian Republic',
#  'Jamaica',
#  'Japan',
#  'Kingdom of Belgium',
#  'Kingdom of Bhutan',
#  'Kingdom of Cambodia',
#  'Kingdom of Denmark',
#  'Kingdom of Lesotho',
#  'Kingdom of Morocco',
#  'Kingdom of Norway',
#  'Kingdom of Spain',
#  'Kingdom of Swaziland',
#  'Kingdom of Thailand',
#  'Kingdom of Tonga',
#  'Kingdom of the Netherlands',
#  'Kyrgyz Republic',
#  "Lao People's Democratic Republic",
#  'Latin America',
#  'Lebanese Republic',
#  'Macedonia',
#  'Malaysia',
#  'Mekong',
#  'Mercosur',
#  'Middle East and North Africa',
#  'Mongolia',
#  'Montenegro',
#  'Multi-Regional',
#  'Nepal',
#  'New Zealand',
#  'Organization of Eastern Caribbean States',
#  'Oriental Republic of Uruguay',
#  'Pacific Islands',
#  "People's Democratic Republic of Algeria",
#  "People's Republic of Bangladesh",
#  "People's Republic of China",
#  'Plurinational State of Bolivia',
#  'Portuguese Republic',
#  'Red Sea and Gulf of Aden',
#  'Republic of Albania',
#  'Republic of Angola',
#  'Republic of Armenia',
#  'Republic of Austria',
#  'Republic of Azerbaijan',
#  'Republic of Belarus',
#  'Republic of Benin',
#  'Republic of Botswana',
#  'Republic of Bulgaria',
#  'Republic of Burundi',
#  'Republic of Cabo Verde',
#  'Republic of Cameroon',
#  'Republic of Chad',
#  'Republic of Chile',
#  'Republic of Colombia',
#  'Republic of Congo',
#  'Republic of Costa Rica',
#  "Republic of Cote d'Ivoire",
#  'Republic of Croatia',
#  'Republic of Cyprus',
#  'Republic of Djibouti',
#  'Republic of Ecuador',
#  'Republic of El Salvador',
#  'Republic of Equatorial Guinea',
#  'Republic of Estonia',
#  'Republic of Fiji',
#  'Republic of Finland',
#  'Republic of Ghana',
#  'Republic of Guatemala',
#  'Republic of Guinea',
#  'Republic of Guinea-Bissau',
#  'Republic of Haiti',
#  'Republic of Honduras',
#  'Republic of Iceland',
#  'Republic of India',
#  'Republic of Indonesia',
#  'Republic of Iraq',
#  'Republic of Kazakhstan',
#  'Republic of Kenya',
#  'Republic of Kiribati',
#  'Republic of Korea',
#  'Republic of Kosovo',
#  'Republic of Latvia',
#  'Republic of Liberia',
#  'Republic of Lithuania',
#  'Republic of Madagascar',
#  'Republic of Malawi',
#  'Republic of Maldives',
#  'Republic of Mali',
#  'Republic of Malta',
#  'Republic of Mauritius',
#  'Republic of Moldova',
#  'Republic of Mozambique',
#  'Republic of Namibia',
#  'Republic of Nicaragua',
#  'Republic of Niger',
#  'Republic of Palau',
#  'Republic of Panama',
#  'Republic of Paraguay',
#  'Republic of Peru',
#  'Republic of Poland',
#  'Republic of Rwanda',
#  'Republic of Senegal',
#  'Republic of Serbia',
#  'Republic of Seychelles',
#  'Republic of Sierra Leone',
#  'Republic of Singapore',
#  'Republic of Slovenia',
#  'Republic of South Africa',
#  'Republic of South Sudan',
#  'Republic of Suriname',
#  'Republic of Tajikistan',
#  'Republic of The Gambia',
#  'Republic of Togo',
#  'Republic of Trinidad and Tobago',
#  'Republic of Tunisia',
#  'Republic of Turkey',
#  'Republic of Uganda',
#  'Republic of Uzbekistan',
#  'Republic of Vanuatu',
#  'Republic of Yemen',
#  'Republic of Zambia',
#  'Republic of Zimbabwe',
#  'Republic of the Marshall Islands',
#  'Republic of the Philippines',
#  'Republic of the Sudan',
#  'Republic of the Union of Myanmar',
#  'Republica Bolivariana de Venezuela',
#  'Romania',
#  'Russian Federation',
#  'Samoa',
#  'Sint Maarten',
#  'Slovak Republic',
#  'Socialist Federal Republic of Yugoslavia',
#  "Socialist People's Libyan Arab Jamahiriy",
#  'Socialist Republic of Vietnam',
#  'Solomon Islands',
#  'Somali Democratic Republic',
#  'South Asia',
#  'Southern Africa',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'State of Eritrea',
#  'State of Israel',
#  'Sultanate of Oman',
#  'Syrian Arab Republic',
#  'Taiwan',
#  'The Independent State of Papua New Guine',
#  'Turkmenistan',
#  'Tuvalu',
#  'Ukraine',
#  'Union of the Comoros',
#  'United Mexican States',
#  'United Republic of Tanzania',
#  'West Bank and Gaza',
#  'Western Africa',
#  'Western Balkans',
#  'World'}

# %% [markdown]
# Yugoslavia officially ended on [April 27th, 1992](https://en.wikipedia.org/wiki/Yugoslavia).
#
# In the code cell below, filter for projects with a 'boardapprovaldate' prior to April 27th, 1992 **and** with 'countryname' Bosnia and Herzegovina, Croatia, Kosovo, Macedonia, Serbia **or** Slovenia. You'll see there are a total of 12 projects in the data set that match this criteria. Save the results in the republics variable

# %%
import datetime

# TODO: filter the projects data set for project boardapprovaldate prior to April 27th, 1992 AND with countryname
#  of either 'Bosnia and Herzegovina', 'Croatia', 'Kosovo', 'Macedonia', 'Serbia', or 'Sovenia'. Store the
#  results in the republics variable
#
#  TODO: so that it's easier to see all the data, keep only these columns:
# ['regionname', 'countryname', 'lendinginstr', 'totalamt', 'boardapprovaldate',
# 'location','GeoLocID', 'GeoLocName', 'Latitude','Longitude','Country', 'project_name']

# TODO: sort the results by boardapprovaldate

republics = projects[['regionname', 'countryname', 'lendinginstr', 'totalamt', 'boardapprovaldate','location','GeoLocID', 'GeoLocName', 'Latitude','Longitude','Country', 'project_name']]
republics = republics[republics['countryname'].apply(lambda x: 'Bosnia' in x 
                                                     or 'Croatia' in x
                                                     or 'Kosovo' in x
                                                     or 'Macedonia' in x
                                                     or 'Serbia' in x
                                                     or 'Sovenia' in x
                                                    )]

republics = republics.sort_values('boardapprovaldate')

# show the results
republics
# Out:
#                     regionname             countryname  \
# 13973  Europe and Central Asia               Macedonia
# 13048  Europe and Central Asia  Bosnia and Herzegovina
# 13050  Europe and Central Asia               Macedonia
# 13049  Europe and Central Asia     Republic of Croatia
# 12228  Europe and Central Asia     Republic of Croatia
# 12062  Europe and Central Asia     Republic of Croatia
# 12063  Europe and Central Asia  Bosnia and Herzegovina
# 12061  Europe and Central Asia     Republic of Croatia
# 11696  Europe and Central Asia     Republic of Croatia
# 10504  Europe and Central Asia               Macedonia
# 10366  Europe and Central Asia     Republic of Croatia
# 10204  Europe and Central Asia     Republic of Croatia
# 10150  Europe and Central Asia               Macedonia
# 10146  Europe and Central Asia     Republic of Croatia
# 10125  Europe and Central Asia               Macedonia
# 10122  Europe and Central Asia               Macedonia
# 9906   Europe and Central Asia  Bosnia and Herzegovina
# 9894   Europe and Central Asia     Republic of Croatia
# 9888   Europe and Central Asia     Republic of Croatia
# 9884   Europe and Central Asia  Bosnia and Herzegovina
# 9883   Europe and Central Asia  Bosnia and Herzegovina
# 9877   Europe and Central Asia  Bosnia and Herzegovina
# 9873   Europe and Central Asia     Republic of Croatia
# 9832   Europe and Central Asia  Bosnia and Herzegovina
# 9821   Europe and Central Asia               Macedonia
# 9825   Europe and Central Asia               Macedonia
# 9768   Europe and Central Asia               Macedonia
# 9747   Europe and Central Asia  Bosnia and Herzegovina
# 9748   Europe and Central Asia  Bosnia and Herzegovina
# 9721   Europe and Central Asia  Bosnia and Herzegovina
# ...                        ...                     ...
# 180    Europe and Central Asia      Republic of Serbia
# 161    Europe and Central Asia      Republic of Serbia
# 15909  Europe and Central Asia      Republic of Serbia
# 15979  Europe and Central Asia      Republic of Serbia
# 15986  Europe and Central Asia  Bosnia and Herzegovina
# 15997  Europe and Central Asia      Republic of Serbia
# 16057  Europe and Central Asia      Republic of Serbia
# 16058  Europe and Central Asia      Republic of Kosovo
# 16116  Europe and Central Asia      Republic of Serbia
# 16186  Europe and Central Asia  Bosnia and Herzegovina
# 16198  Europe and Central Asia     Republic of Croatia
# 16220  Europe and Central Asia               Macedonia
# 16221  Europe and Central Asia     Republic of Croatia
# 16259  Europe and Central Asia      Republic of Kosovo
# 16290  Europe and Central Asia  Bosnia and Herzegovina
# 16318  Europe and Central Asia      Republic of Serbia
# 16365  Europe and Central Asia  Bosnia and Herzegovina
# 16455  Europe and Central Asia  Bosnia and Herzegovina
# 16698  Europe and Central Asia               Macedonia
# 16768  Europe and Central Asia      Republic of Serbia
# 16807  Europe and Central Asia      Republic of Kosovo
# 16899  Europe and Central Asia      Republic of Kosovo
# 16969  Europe and Central Asia     Republic of Croatia
# 17079  Europe and Central Asia     Republic of Croatia
# 17212  Europe and Central Asia     Republic of Croatia
# 17291  Europe and Central Asia               Macedonia
# 17307  Europe and Central Asia     Republic of Croatia
# 17308  Europe and Central Asia      Republic of Serbia
# 17345  Europe and Central Asia               Macedonia
# 17354  Europe and Central Asia               Macedonia
#
#                                  lendinginstr   totalamt  \
# 13973                Specific Investment Loan   24000000
# 13048                Specific Investment Loan          0
# 13050                Specific Investment Loan          0
# 13049                Specific Investment Loan          0
# 12228             Financial Intermediary Loan          0
# 12062  Sector Investment and Maintenance Loan          0
# 12063  Sector Investment and Maintenance Loan          0
# 12061  Sector Investment and Maintenance Loan          0
# 11696                Specific Investment Loan   28000000
# 10504              Structural Adjustment Loan   80000000
# 10366                 Emergency Recovery Loan  128000000
# 10204                Specific Investment Loan   40000000
# 10150                Specific Investment Loan   24000000
# 10146  Sector Investment and Maintenance Loan   80000000
# 10125                Specific Investment Loan   14000000
# 10122                  Sector Adjustment Loan   85000000
# 9906                  Emergency Recovery Loan          0
# 9894                 Specific Investment Loan   17000000
# 9888                Technical Assistance Loan    5000000
# 9884                  Emergency Recovery Loan          0
# 9883                  Emergency Recovery Loan          0
# 9877                  Emergency Recovery Loan          0
# 9873   Sector Investment and Maintenance Loan    9500000
# 9832                  Emergency Recovery Loan          0
# 9821                 Specific Investment Loan    7900000
# 9825                 Specific Investment Loan   12000000
# 9768                 Specific Investment Loan   16900000
# 9747                  Emergency Recovery Loan    5000000
# 9748                  Emergency Recovery Loan    5000000
# 9721                  Emergency Recovery Loan   10000000
# ...                                       ...        ...
# 180              Investment Project Financing   31100000
# 161              Investment Project Financing          0
# 15909                Specific Investment Loan   14000000
# 15979                Specific Investment Loan   40000000
# 15986              Development Policy Lending   20000000
# 15997              Development Policy Lending   55000000
# 16057                Specific Investment Loan   80000000
# 16058              Development Policy Lending    5000000
# 16116              Development Policy Lending  100000000
# 16186                Specific Investment Loan   30000000
# 16198                Specific Investment Loan   26400000
# 16220                Specific Investment Loan   70000000
# 16221                Specific Investment Loan   75000000
# 16259            Investment Project Financing   40000000
# 16290              Development Policy Lending  100000000
# 16318              Development Policy Lending  100000000
# 16365                  Adaptable Program Loan    2500000
# 16455            Investment Project Financing   50000000
# 16698            Investment Project Financing   33400000
# 16768            Investment Project Financing   50000000
# 16807            Investment Project Financing   25000000
# 16899            Investment Project Financing   25000000
# 16969            Investment Project Financing   24070000
# 17079                Specific Investment Loan  100000000
# 17212                Specific Investment Loan   18300000
# 17291                Specific Investment Loan   15530000
# 17307                Specific Investment Loan   30000000
# 17308                Specific Investment Loan   10000000
# 17345               Technical Assistance Loan    1000000
# 17354                Specific Investment Loan   20000000
#
#               boardapprovaldate  \
# 13973 1980-02-01 00:00:00+00:00
# 13048 1983-07-26 00:00:00+00:00
# 13050 1983-07-26 00:00:00+00:00
# 13049 1983-07-26 00:00:00+00:00
# 12228 1987-03-31 00:00:00+00:00
# 12062 1987-10-13 00:00:00+00:00
# 12063 1987-10-13 00:00:00+00:00
# 12061 1987-10-13 00:00:00+00:00
# 11696 1989-05-23 00:00:00+00:00
# 10504 1994-02-08 00:00:00+00:00
# 10366 1994-06-21 00:00:00+00:00
# 10204 1995-02-14 00:00:00+00:00
# 10150 1995-04-18 00:00:00+00:00
# 10146 1995-04-20 00:00:00+00:00
# 10125 1995-05-16 00:00:00+00:00
# 10122 1995-05-16 00:00:00+00:00
# 9906  1996-03-01 00:00:00+00:00
# 9894  1996-03-21 00:00:00+00:00
# 9888  1996-03-26 00:00:00+00:00
# 9884  1996-03-28 00:00:00+00:00
# 9883  1996-03-28 00:00:00+00:00
# 9877  1996-03-29 00:00:00+00:00
# 9873  1996-04-04 00:00:00+00:00
# 9832  1996-05-14 00:00:00+00:00
# 9821  1996-05-16 00:00:00+00:00
# 9825  1996-05-16 00:00:00+00:00
# 9768  1996-06-20 00:00:00+00:00
# 9747  1996-06-28 00:00:00+00:00
# 9748  1996-06-28 00:00:00+00:00
# 9721  1996-07-30 00:00:00+00:00
# ...                         ...
# 180   2018-03-29 00:00:00+00:00
# 161   2018-04-05 00:00:00+00:00
# 15909                       NaT
# 15979                       NaT
# 15986                       NaT
# 15997                       NaT
# 16057                       NaT
# 16058                       NaT
# 16116                       NaT
# 16186                       NaT
# 16198                       NaT
# 16220                       NaT
# 16221                       NaT
# 16259                       NaT
# 16290                       NaT
# 16318                       NaT
# 16365                       NaT
# 16455                       NaT
# 16698                       NaT
# 16768                       NaT
# 16807                       NaT
# 16899                       NaT
# 16969                       NaT
# 17079                       NaT
# 17212                       NaT
# 17291                       NaT
# 17307                       NaT
# 17308                       NaT
# 17345                       NaT
# 17354                       NaT
#
#                                                 location  \
# 13973                                                NaN
# 13048                                                NaN
# 13050                                                NaN
# 13049                                                NaN
# 12228                                                NaN
# 12062                                                NaN
# 12063                                                NaN
# 12061                                                NaN
# 11696                                                NaN
# 10504                                                NaN
# 10366                                                NaN
# 10204                                                NaN
# 10150                                                NaN
# 10146                                                NaN
# 10125                                                NaN
# 10122                                                NaN
# 9906                                                 NaN
# 9894                                                 NaN
# 9888                                                 NaN
# 9884                                                 NaN
# 9883                                                 NaN
# 9877                                                 NaN
# 9873                                                 NaN
# 9832                                                 NaN
# 9821                                                 NaN
# 9825                                                 NaN
# 9768                                                 NaN
# 9747                                                 NaN
# 9748                                                 NaN
# 9721                                                 NaN
# ...                                                  ...
# 180    0000787657!$!Nis!$!43.32472!$!21.90333!$!RS;00...
# 161       0006290252!$!Serbia!$!44.81892!$!20.45998!$!RS
# 15909                                                NaN
# 15979                                                NaN
# 15986                                                NaN
# 15997                                                NaN
# 16057                                                NaN
# 16058                                                NaN
# 16116                                                NaN
# 16186                                                NaN
# 16198                                                NaN
# 16220                                                NaN
# 16221                                                NaN
# 16259                                                NaN
# 16290                                                NaN
# 16318                                                NaN
# 16365                                                NaN
# 16455  0003229999!$!Federation of Bosnia and Herzegov...
# 16698                                                NaN
# 16768                                                NaN
# 16807                                                NaN
# 16899                                                NaN
# 16969                                                NaN
# 17079                                                NaN
# 17212                                                NaN
# 17291                                                NaN
# 17307                                                NaN
# 17308                                                NaN
# 17345                                                NaN
# 17354                                                NaN
#
#                                                 GeoLocID  \
# 13973                                                NaN
# 13048                                                NaN
# 13050                                                NaN
# 13049                                                NaN
# 12228                                                NaN
# 12062                                                NaN
# 12063                                                NaN
# 12061                                                NaN
# 11696                                                NaN
# 10504                                                NaN
# 10366                                                NaN
# 10204                                                NaN
# 10150                                                NaN
# 10146                                                NaN
# 10125                                                NaN
# 10122                                                NaN
# 9906                                                 NaN
# 9894                                                 NaN
# 9888                                                 NaN
# 9884                                                 NaN
# 9883                                                 NaN
# 9877                                                 NaN
# 9873                                                 NaN
# 9832                                                 NaN
# 9821                                                 NaN
# 9825                                                 NaN
# 9768                                                 NaN
# 9747                                                 NaN
# 9748                                                 NaN
# 9721                                                 NaN
# ...                                                  ...
# 180    0000787657;0000789128;0000789485;0003194360;00...
# 161                                           0006290252
# 15909                                                NaN
# 15979                                                NaN
# 15986                                                NaN
# 15997                                                NaN
# 16057                                                NaN
# 16058                                                NaN
# 16116                                                NaN
# 16186                                                NaN
# 16198                                                NaN
# 16220                                                NaN
# 16221                                                NaN
# 16259                                                NaN
# 16290                                                NaN
# 16318                                                NaN
# 16365                                                NaN
# 16455                                         0003229999
# 16698                                                NaN
# 16768                                                NaN
# 16807                                                NaN
# 16899                                                NaN
# 16969                                                NaN
# 17079                                                NaN
# 17212                                                NaN
# 17291                                                NaN
# 17307                                                NaN
# 17308                                                NaN
# 17345                                                NaN
# 17354                                                NaN
#
#                                             GeoLocName  \
# 13973                                              NaN
# 13048                                              NaN
# 13050                                              NaN
# 13049                                              NaN
# 12228                                              NaN
# 12062                                              NaN
# 12063                                              NaN
# 12061                                              NaN
# 11696                                              NaN
# 10504                                              NaN
# 10366                                              NaN
# 10204                                              NaN
# 10150                                              NaN
# 10146                                              NaN
# 10125                                              NaN
# 10122                                              NaN
# 9906                                               NaN
# 9894                                               NaN
# 9888                                               NaN
# 9884                                               NaN
# 9883                                               NaN
# 9877                                               NaN
# 9873                                               NaN
# 9832                                               NaN
# 9821                                               NaN
# 9825                                               NaN
# 9768                                               NaN
# 9747                                               NaN
# 9748                                               NaN
# 9721                                               NaN
# ...                                                ...
# 180    Nis;Kragujevac;Kladovo;Novi Sad;Serbia;Belgrade
# 161                                             Serbia
# 15909                                              NaN
# 15979                                              NaN
# 15986                                              NaN
# 15997                                              NaN
# 16057                                              NaN
# 16058                                              NaN
# 16116                                              NaN
# 16186                                              NaN
# 16198                                              NaN
# 16220                                              NaN
# 16221                                              NaN
# 16259                                              NaN
# 16290                                              NaN
# 16318                                              NaN
# 16365                                              NaN
# 16455             Federation of Bosnia and Herzegovina
# 16698                                              NaN
# 16768                                              NaN
# 16807                                              NaN
# 16899                                              NaN
# 16969                                              NaN
# 17079                                              NaN
# 17212                                              NaN
# 17291                                              NaN
# 17307                                              NaN
# 17308                                              NaN
# 17345                                              NaN
# 17354                                              NaN
#
#                                                 Latitude  \
# 13973                                                NaN
# 13048                                                NaN
# 13050                                                NaN
# 13049                                                NaN
# 12228                                                NaN
# 12062                                                NaN
# 12063                                                NaN
# 12061                                                NaN
# 11696                                                NaN
# 10504                                                NaN
# 10366                                                NaN
# 10204                                                NaN
# 10150                                                NaN
# 10146                                                NaN
# 10125                                                NaN
# 10122                                                NaN
# 9906                                                 NaN
# 9894                                                 NaN
# 9888                                                 NaN
# 9884                                                 NaN
# 9883                                                 NaN
# 9877                                                 NaN
# 9873                                                 NaN
# 9832                                                 NaN
# 9821                                                 NaN
# 9825                                                 NaN
# 9768                                                 NaN
# 9747                                                 NaN
# 9748                                                 NaN
# 9721                                                 NaN
# ...                                                  ...
# 180    43.32472;44.01667;44.60667;45.25167;44.81892;4...
# 161                                             44.81892
# 15909                                                NaN
# 15979                                                NaN
# 15986                                                NaN
# 15997                                                NaN
# 16057                                                NaN
# 16058                                                NaN
# 16116                                                NaN
# 16186                                                NaN
# 16198                                                NaN
# 16220                                                NaN
# 16221                                                NaN
# 16259                                                NaN
# 16290                                                NaN
# 16318                                                NaN
# 16365                                                NaN
# 16455                                                 44
# 16698                                                NaN
# 16768                                                NaN
# 16807                                                NaN
# 16899                                                NaN
# 16969                                                NaN
# 17079                                                NaN
# 17212                                                NaN
# 17291                                                NaN
# 17307                                                NaN
# 17308                                                NaN
# 17345                                                NaN
# 17354                                                NaN
#
#                                                Longitude            Country  \
# 13973                                                NaN                NaN
# 13048                                                NaN                NaN
# 13050                                                NaN                NaN
# 13049                                                NaN                NaN
# 12228                                                NaN                NaN
# 12062                                                NaN                NaN
# 12063                                                NaN                NaN
# 12061                                                NaN                NaN
# 11696                                                NaN                NaN
# 10504                                                NaN                NaN
# 10366                                                NaN                NaN
# 10204                                                NaN                NaN
# 10150                                                NaN                NaN
# 10146                                                NaN                NaN
# 10125                                                NaN                NaN
# 10122                                                NaN                NaN
# 9906                                                 NaN                NaN
# 9894                                                 NaN                NaN
# 9888                                                 NaN                NaN
# 9884                                                 NaN                NaN
# 9883                                                 NaN                NaN
# 9877                                                 NaN                NaN
# 9873                                                 NaN                NaN
# 9832                                                 NaN                NaN
# 9821                                                 NaN                NaN
# 9825                                                 NaN                NaN
# 9768                                                 NaN                NaN
# 9747                                                 NaN                NaN
# 9748                                                 NaN                NaN
# 9721                                                 NaN                NaN
# ...                                                  ...                ...
# 180    21.90333;20.91667;22.61194;19.83694;20.45998;2...  RS;RS;RS;RS;RS;RS
# 161                                             20.45998                 RS
# 15909                                                NaN                NaN
# 15979                                                NaN                NaN
# 15986                                                NaN                NaN
# 15997                                                NaN                NaN
# 16057                                                NaN                NaN
# 16058                                                NaN                NaN
# 16116                                                NaN                NaN
# 16186                                                NaN                NaN
# 16198                                                NaN                NaN
# 16220                                                NaN                NaN
# 16221                                                NaN                NaN
# 16259                                                NaN                NaN
# 16290                                                NaN                NaN
# 16318                                                NaN                NaN
# 16365                                                NaN                NaN
# 16455                                           17.58333                 BA
# 16698                                                NaN                NaN
# 16768                                                NaN                NaN
# 16807                                                NaN                NaN
# 16899                                                NaN                NaN
# 16969                                                NaN                NaN
# 17079                                                NaN                NaN
# 17212                                                NaN                NaN
# 17291                                                NaN                NaN
# 17307                                                NaN                NaN
# 17308                                                NaN                NaN
# 17345                                                NaN                NaN
# 17354                                                NaN                NaN
#
#                                             project_name
# 13973   Agriculture & Agroindustry 2 Project (Macedonia)
# 13048                                    POWER TRANS.III
# 13050                                    POWER TRANS.III
# 13049                                    POWER TRANS.III
# 12228                                IND.ENERGY EFFIC. I
# 12062                                  HIGHWAY SECTOR II
# 12063                                  HIGHWAY SECTOR II
# 12061                                  HIGHWAY SECTOR II
# 11696             Istria Water Supply & Sewerage Project
# 10504                             Economic Recovery Loan
# 10366                   Emergency Reconstruction Project
# 10204                                     Health Project
# 10150                       Transit Facilitation Project
# 10146                             Highway Sector Project
# 10125                              Social Reform Project
# 10122  Financial & Enterprise Sector Adjustment Credi...
# 9906                          Emergency Recovery Project
# 9894                     Farmer Support Services Project
# 9888   Technical Assistance Project in Support of Ent...
# 9884   Water; Sanitation and Solid Waste Urgent Works...
# 9883               Emergency Farm Reconstruction Project
# 9877          Emergency Reconstruction Transport Project
# 9873                 Capital Markets Development Project
# 9832   Emergency District Heating Rehabilitation Project
# 9821                      Private Farmer Support Project
# 9825                  Private Sector Development Project
# 9768                    Health Sector Transition Project
# 9747                  War Victims Rehabilitation Project
# 9748          Emergency Education Reconstruction Project
# 9721         Emergency Public Works & Employment Project
# ...                                                  ...
# 180    Additional Financing for Second Serbia Health ...
# 161     Serbia Public Sector Accounting Reform Techni...
# 15909               Public Expenditure Capacity Building
# 15979      SERBIA MUNICIPAL WATER AND SANITATION PROJECT
# 15986  Program Development Policy Credit (formerly Co...
# 15997  Public Sector Development Policy Loan (PSDPL) ...
# 16057                             Serbian Railway Reform
# 16058                        Fiscal Policy Support Grant
# 16116  Programmatic Private and Financial Development...
# 16186               Sava Waterway Rehabilitation Project
# 16198    Disaster Risk Mitigation and Adaptation Project
# 16220  Lukovo Pole Water Regulation and Renewable Ene...
# 16221                     Irrigation Development Project
# 16259                               Kosovo Power Project
# 16290                                     Bosnia PE DPL2
# 16318                                            PEDPL 3
# 16365      SEEC Catastrophe Risk Insurance Facility APL2
# 16455                  Health Sector Improvement Project
# 16698              Macedonia Social Services Improvement
# 16768           Tax Administration Modernization Project
# 16807                      Kosovo Digital Economy (KODE)
# 16899      Kosovo Financial Sector Strengthening Project
# 16969  Integrated Land Administration System - Additi...
# 17079    Zagreb East Combined Cycle Power & Heat Project
# 17212                 Split Mun Revitalization (Dropped)
# 17291                         Trade Facilitation Project
# 17307                   Croatia District Heating Project
# 17308         LOCAL INITIATIVES (formerly Micro Finance)
# 17345  Public Sector Management Technical Assistance ...
# 17354                  HEALTH SECTOR DEVELOPMENT PROJECT
#
# [375 rows x 12 columns]

# %% [markdown]
# Are these projects also represented in the data labeled Yugoslavia? In the code cell below, filter for Yugoslavia projects approved between February 1st, 1980 and May 23rd, 1989 which are the minimum and maximum dates in the results above. Store the results in the yugoslavia variable.
#
# The goal is to see if there are any projects represented more than once in the data set.

# %%
projects['boardapprovaldate']
# Out:
# 0       2018-06-28 00:00:00+00:00
# 1       2018-06-28 00:00:00+00:00
# 2       2018-06-28 00:00:00+00:00
# 3       2018-06-27 00:00:00+00:00
# 4       2018-06-27 00:00:00+00:00
# 5       2018-06-27 00:00:00+00:00
# 6       2018-06-27 00:00:00+00:00
# 7       2018-06-27 00:00:00+00:00
# 8       2018-06-27 00:00:00+00:00
# 9       2018-06-27 00:00:00+00:00
# 10      2018-06-27 00:00:00+00:00
# 11      2018-06-27 00:00:00+00:00
# 12      2018-06-27 00:00:00+00:00
# 13      2018-06-27 00:00:00+00:00
# 14      2018-06-27 00:00:00+00:00
# 15      2018-06-27 00:00:00+00:00
# 16      2018-06-27 00:00:00+00:00
# 17      2018-06-27 00:00:00+00:00
# 18      2018-06-26 00:00:00+00:00
# 19      2018-06-26 00:00:00+00:00
# 20      2018-06-26 00:00:00+00:00
# 21      2018-06-26 00:00:00+00:00
# 22      2018-06-26 00:00:00+00:00
# 23      2018-06-25 00:00:00+00:00
# 24      2018-06-23 00:00:00+00:00
# 25      2018-06-22 00:00:00+00:00
# 26      2018-06-22 00:00:00+00:00
# 27      2018-06-22 00:00:00+00:00
# 28      2018-06-22 00:00:00+00:00
# 29      2018-06-22 00:00:00+00:00
#                    ...
# 18218   1950-09-13 00:00:00+00:00
# 18219   1950-08-25 00:00:00+00:00
# 18220   1950-08-22 00:00:00+00:00
# 18221   1950-07-07 00:00:00+00:00
# 18222   1950-07-07 00:00:00+00:00
# 18223   1950-06-14 00:00:00+00:00
# 18224   1950-05-26 00:00:00+00:00
# 18225   1950-04-28 00:00:00+00:00
# 18226   1950-04-18 00:00:00+00:00
# 18227   1949-12-14 00:00:00+00:00
# 18228   1949-10-17 00:00:00+00:00
# 18229   1949-10-13 00:00:00+00:00
# 18230   1949-09-29 00:00:00+00:00
# 18231   1949-08-19 00:00:00+00:00
# 18232   1949-08-18 00:00:00+00:00
# 18233   1949-07-26 00:00:00+00:00
# 18234   1949-07-06 00:00:00+00:00
# 18235   1949-02-08 00:00:00+00:00
# 18236   1949-01-27 00:00:00+00:00
# 18237   1949-01-06 00:00:00+00:00
# 18238   1949-01-06 00:00:00+00:00
# 18239   1948-07-01 00:00:00+00:00
# 18240   1948-07-01 00:00:00+00:00
# 18241   1948-07-01 00:00:00+00:00
# 18242   1948-03-25 00:00:00+00:00
# 18243   1948-03-25 00:00:00+00:00
# 18244   1947-08-28 00:00:00+00:00
# 18245   1947-08-22 00:00:00+00:00
# 18246   1947-08-07 00:00:00+00:00
# 18247   1947-05-09 00:00:00+00:00
# Name: boardapprovaldate, Length: 18248, dtype: datetime64[ns, UTC]

# %%
datetime.date(1980, 2, 1, tzinfo=timezone.utc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-dfe307e14cb1> in <module>
# ----> 1 datetime.date(1980, 2, 1, tzinfo=timezone.utc)
#
# NameError: name 'timezone' is not defined

# %%
# TODO: Filter the projects data for Yugoslavia projects between
# February 1st, 1980 and May 23rd, 1989. Store the results in the
# Yugoslavia variable. Keep the same columns as the previous code cell.
# Sort the values by boardapprovaldate

yugoslavia = projects[(projects['countryname'].str.contains('Yugoslavia')) & 
         (projects['boardapprovaldate'] >= datetime.date(1980, 2, 1)) &
         (projects['boardapprovaldate'] <= datetime.date(1989, 5, 23))][['regionname', 
                                                                   'countryname', 
                                                                   'lendinginstr', 
                                                                   'totalamt', 
                                                                   'boardapprovaldate',
                                                               'location', 
                                                               'GeoLocID', 
                                                               'GeoLocName',
                                                               'Latitude', 
                                                               'Longitude', 
                                                               'Country', 
                                                                        'project_name']].sort_values('boardapprovaldate')

# show the results
yugoslavia
# Out:
# /root/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   import sys
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-7270f63e3f9a> in <module>
#       5
#       6 yugoslavia = projects[(projects['countryname'].str.contains('Yugoslavia')) &
# ----> 7          (projects['boardapprovaldate'] >= datetime.date(1980, 2, 1)) &
#       8          (projects['boardapprovaldate'] <= datetime.date(1989, 5, 23))][['regionname',
#       9                                                                    'countryname',
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1714
#    1715             res_values = dispatch_to_index_op(op, self, other,
# -> 1716                                               pd.DatetimeIndex)
#    1717
#    1718             return self._constructor(res_values, index=self.index,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in dispatch_to_index_op(op, left, right, index_class)
#    1189         left_idx = left_idx._shallow_copy(freq=None)
#    1190     try:
# -> 1191         result = op(left_idx, right)
#    1192     except NullFrequencyError:
#    1193         # DatetimeIndex and TimedeltaIndex with freq == None raise ValueError
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/datetimelike.py in wrapper(self, other)
#     115                 other = other._values
#     116
# --> 117             result = op(self._data, maybe_unwrap_index(other))
#     118             return result
#     119
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in wrapper(self, other)
#     140             if isinstance(other, (datetime, np.datetime64)):
#     141                 # GH#18435 strings get a pass from tzawareness compat
# --> 142                 self._assert_tzawareness_compat(other)
#     143
#     144             try:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in _assert_tzawareness_compat(self, other)
#     698                                 'datetime-like objects.')
#     699         elif other_tz is None:
# --> 700             raise TypeError('Cannot compare tz-naive and tz-aware '
#     701                             'datetime-like objects')
#     702
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects

# %%
yugoslavia = projects[(projects['countryname'].str.contains('Yugoslavia')) & 
         (projects['boardapprovaldate'] >= "1980-02-01") &
         (projects['boardapprovaldate'] <= "1989-05-23")][['regionname', 
                                                                   'countryname', 
                                                                   'lendinginstr', 
                                                                   'totalamt', 
                                                                   'boardapprovaldate',
                                                               'location', 
                                                               'GeoLocID', 
                                                               'GeoLocName',
                                                               'Latitude', 
                                                               'Longitude', 
                                                               'Country', 
                                                                        'project_name']].sort_values('boardapprovaldate')

# show the results
yugoslavia
# Out:
#                     regionname                               countryname  \
# 13966  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13937  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13773  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13706  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13647  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13629  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13555  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13526  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13412  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13402  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13365  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13231  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13099  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13098  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13071  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13053  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13046  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13047  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13041  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12809  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12677  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12671  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12617  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12577  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12375  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12227  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12225  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12060  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 11866  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 11695  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 11694  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
#
#                                  lendinginstr   totalamt  \
# 13966             Financial Intermediary Loan   86000000
# 13937                Specific Investment Loan  125000000
# 13773             Financial Intermediary Loan  110000000
# 13706             Financial Intermediary Loan   87000000
# 13647                Specific Investment Loan   34000000
# 13629             Financial Intermediary Loan   90000000
# 13555             Financial Intermediary Loan   80000000
# 13526                Specific Investment Loan   41000000
# 13412             Financial Intermediary Loan   66000000
# 13402                Specific Investment Loan   35000000
# 13365                Specific Investment Loan   34600000
# 13231                Specific Investment Loan   30000000
# 13099             Financial Intermediary Loan  136000000
# 13098             Financial Intermediary Loan   79000000
# 13071              Structural Adjustment Loan  275000000
# 13053  Sector Investment and Maintenance Loan  110000000
# 13046             Financial Intermediary Loan   70000000
# 13047                Specific Investment Loan  120000000
# 13041                Specific Investment Loan   61000000
# 12809             Financial Intermediary Loan   40000000
# 12677                Specific Investment Loan  125000000
# 12671                  Sector Adjustment Loan   90000000
# 12617                Specific Investment Loan   35000000
# 12577                Specific Investment Loan   92500000
# 12375  Sector Investment and Maintenance Loan  121500000
# 12227             Financial Intermediary Loan          0
# 12225             Financial Intermediary Loan   90000000
# 12060  Sector Investment and Maintenance Loan   68000000
# 11866             Financial Intermediary Loan  120000000
# 11695                Specific Investment Loan   60000000
# 11694  Sector Investment and Maintenance Loan  138000000
#
#               boardapprovaldate location GeoLocID GeoLocName Latitude  \
# 13966 1980-02-26 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13937 1980-03-25 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13773 1980-10-28 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13706 1981-03-03 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13647 1981-04-28 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13629 1981-05-14 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13555 1981-07-14 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13526 1981-11-10 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13412 1982-04-27 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13402 1982-05-04 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13365 1982-05-27 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13231 1983-01-25 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13099 1983-06-09 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13098 1983-06-09 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13071 1983-06-28 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13053 1983-07-19 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13046 1983-07-26 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13047 1983-07-26 00:00:00+00:00      NaN      NaN        NaN      NaN
# 13041 1983-08-02 00:00:00+00:00      NaN      NaN        NaN      NaN
# 12809 1984-07-31 00:00:00+00:00      NaN      NaN        NaN      NaN
# 12677 1985-04-30 00:00:00+00:00      NaN      NaN        NaN      NaN
# 12671 1985-05-03 00:00:00+00:00      NaN      NaN        NaN      NaN
# 12617 1985-06-06 00:00:00+00:00      NaN      NaN        NaN      NaN
# 12577 1985-06-27 00:00:00+00:00      NaN      NaN        NaN      NaN
# 12375 1986-06-10 00:00:00+00:00      NaN      NaN        NaN      NaN
# 12227 1987-03-31 00:00:00+00:00      NaN      NaN        NaN      NaN
# 12225 1987-03-31 00:00:00+00:00      NaN      NaN        NaN      NaN
# 12060 1987-10-13 00:00:00+00:00      NaN      NaN        NaN      NaN
# 11866 1988-06-29 00:00:00+00:00      NaN      NaN        NaN      NaN
# 11695 1989-05-23 00:00:00+00:00      NaN      NaN        NaN      NaN
# 11694 1989-05-23 00:00:00+00:00      NaN      NaN        NaN      NaN
#
#       Longitude Country                                       project_name
# 13966       NaN     NaN                    Agriculture Credit Project (03)
# 13937       NaN     NaN                               Highway Project (11)
# 13773       NaN     NaN                     Industrial Credit Project (05)
# 13706       NaN     NaN           Morava Regional Development Project (02)
# 13647       NaN     NaN                             Kosovo Railway Project
# 13629       NaN     NaN             Kosovo Agriculture Development Project
# 13555       NaN     NaN     Macedonia Agriculture Development Project (03)
# 13526       NaN     NaN                        Kosovo Water Supply Project
# 13412       NaN     NaN                     Industrial Credit Project (06)
# 13402       NaN     NaN  Bosnia Herzegovina Agriculture Development Pro...
# 13365       NaN     NaN                         Semberija Drainage Project
# 13231       NaN     NaN    Tuzla Region Water Supply & Environment Project
# 13099       NaN     NaN                Serbia Regional Development Project
# 13098       NaN     NaN                Kosovo Regional Development Project
# 13071       NaN     NaN            Structural Adjustment Loan Project (01)
# 13053       NaN     NaN                               Railway Project (06)
# 13046       NaN     NaN                     Industrial Credit Project (07)
# 13047       NaN     NaN  Power Transmission Project (03) Energy Managem...
# 13041       NaN     NaN                                  MOSTAR POWER(SAP)
# 12809       NaN     NaN            Montenegro Regional Development Project
# 12677       NaN     NaN                     Visegrad Hydroelectric Project
# 12671       NaN     NaN                     Fertilizer Sector Loan Project
# 12617       NaN     NaN                Bosnia Herzegovina Forestry Project
# 12577       NaN     NaN                           Petroleum Sector Project
# 12375       NaN     NaN                             Highway Sector Project
# 12227       NaN     NaN                                IND.ENERGY EFFIC. I
# 12225       NaN     NaN         Energy Conservation & Substitution Project
# 12060       NaN     NaN                        Highway Sector Project (02)
# 11866       NaN     NaN                 Export Oriented Industries Project
# 11695       NaN     NaN             Istria Water Supply & Sewerage Project
# 11694       NaN     NaN                               Railway Project (07)

# %% [markdown]
# And as a final step, try to see if there are any projects in the republics variable and yugoslavia variable that could be the same project.
#
# There are multiple ways to do that. As a suggestion, find unique dates in the republics variable. Then separately find unique dates in the yugoslavia variable. Concatenate (ie append) the results together. And then count the number of times each date occurs in this list. If a date occurs twice, that means the same boardapprovaldate appeared in both the Yugoslavia data as well as in the republics data.
#
# You'll should find that there are three suspicious cases:
#
# * July 26th, 1983
# * March 31st, 1987
# * October 13th, 1987
# * May 23rd, 1989

# %%
republics.boardapprovaldate
# Out:
# 13973   1980-02-01 00:00:00+00:00
# 13048   1983-07-26 00:00:00+00:00
# 13050   1983-07-26 00:00:00+00:00
# 13049   1983-07-26 00:00:00+00:00
# 12228   1987-03-31 00:00:00+00:00
# 12062   1987-10-13 00:00:00+00:00
# 12063   1987-10-13 00:00:00+00:00
# 12061   1987-10-13 00:00:00+00:00
# 11696   1989-05-23 00:00:00+00:00
# 10504   1994-02-08 00:00:00+00:00
# 10366   1994-06-21 00:00:00+00:00
# 10204   1995-02-14 00:00:00+00:00
# 10150   1995-04-18 00:00:00+00:00
# 10146   1995-04-20 00:00:00+00:00
# 10125   1995-05-16 00:00:00+00:00
# 10122   1995-05-16 00:00:00+00:00
# 9906    1996-03-01 00:00:00+00:00
# 9894    1996-03-21 00:00:00+00:00
# 9888    1996-03-26 00:00:00+00:00
# 9884    1996-03-28 00:00:00+00:00
# 9883    1996-03-28 00:00:00+00:00
# 9877    1996-03-29 00:00:00+00:00
# 9873    1996-04-04 00:00:00+00:00
# 9832    1996-05-14 00:00:00+00:00
# 9821    1996-05-16 00:00:00+00:00
# 9825    1996-05-16 00:00:00+00:00
# 9768    1996-06-20 00:00:00+00:00
# 9747    1996-06-28 00:00:00+00:00
# 9748    1996-06-28 00:00:00+00:00
# 9721    1996-07-30 00:00:00+00:00
#                    ...
# 180     2018-03-29 00:00:00+00:00
# 161     2018-04-05 00:00:00+00:00
# 15909                         NaT
# 15979                         NaT
# 15986                         NaT
# 15997                         NaT
# 16057                         NaT
# 16058                         NaT
# 16116                         NaT
# 16186                         NaT
# 16198                         NaT
# 16220                         NaT
# 16221                         NaT
# 16259                         NaT
# 16290                         NaT
# 16318                         NaT
# 16365                         NaT
# 16455                         NaT
# 16698                         NaT
# 16768                         NaT
# 16807                         NaT
# 16899                         NaT
# 16969                         NaT
# 17079                         NaT
# 17212                         NaT
# 17291                         NaT
# 17307                         NaT
# 17308                         NaT
# 17345                         NaT
# 17354                         NaT
# Name: boardapprovaldate, Length: 375, dtype: datetime64[ns, UTC]

# %%
republics.boardapprovaldate.unique()
# Out:
# <DatetimeArray>
# ['1980-02-01 00:00:00+00:00', '1983-07-26 00:00:00+00:00',
#  '1987-03-31 00:00:00+00:00', '1987-10-13 00:00:00+00:00',
#  '1989-05-23 00:00:00+00:00', '1994-02-08 00:00:00+00:00',
#  '1994-06-21 00:00:00+00:00', '1995-02-14 00:00:00+00:00',
#  '1995-04-18 00:00:00+00:00', '1995-04-20 00:00:00+00:00',
#  ...
#  '2017-05-18 00:00:00+00:00', '2017-09-01 00:00:00+00:00',
#  '2017-09-08 00:00:00+00:00', '2017-10-04 00:00:00+00:00',
#  '2017-11-02 00:00:00+00:00', '2017-12-07 00:00:00+00:00',
#  '2018-03-20 00:00:00+00:00', '2018-03-29 00:00:00+00:00',
#  '2018-04-05 00:00:00+00:00',                       'NaT']
# Length: 265, dtype: datetime64[ns, UTC]

# %%
import numpy as np

# TODO: find the unique dates in the republics variable
republic_unique_dates = list(republics.boardapprovaldate.unique())

# TODO: find the unique dates in the yugoslavia variable
yugoslavia_unique_dates = list(yugoslavia.boardapprovaldate.unique())

# TODO: make a list of the results appending one list to the other
dates = republic_unique_dates + yugoslavia_unique_dates

# TODO: print out the dates that appeared twice in the results

import collections

for date, count in collections.Counter(dates).items():
    if count ==2:
        print(date)
# Out:
# 1983-07-26 00:00:00+00:00
# 1987-03-31 00:00:00+00:00
# 1987-10-13 00:00:00+00:00
# 1989-05-23 00:00:00+00:00

# %%
import numpy as np

# TODO: find the unique dates in the republics variable
republic_unique_dates = republics['boardapprovaldate'].unique()

# TODO: find the unique dates in the yugoslavia variable
yugoslavia_unique_dates = yugoslavia['boardapprovaldate'].unique()

# TODO: make a list of the results appending one list to the other
dates = np.append(republic_unique_dates, yugoslavia_unique_dates)

# TODO: print out the dates that appeared twice in the results
unique_dates, count = np.unique(dates, return_counts=True)

for i in range(len(unique_dates)):
    if count[i] == 2:
        print(unique_dates[i])

# %%
yugoslavia[yugoslavia['boardapprovaldate']=="1983-07-26"]
# Out:
#                     regionname                               countryname  \
# 13046  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13047  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
#
#                       lendinginstr   totalamt         boardapprovaldate  \
# 13046  Financial Intermediary Loan   70000000 1983-07-26 00:00:00+00:00
# 13047     Specific Investment Loan  120000000 1983-07-26 00:00:00+00:00
#
#       location GeoLocID GeoLocName Latitude Longitude Country  \
# 13046      NaN      NaN        NaN      NaN       NaN     NaN
# 13047      NaN      NaN        NaN      NaN       NaN     NaN
#
#                                             project_name
# 13046                     Industrial Credit Project (07)
# 13047  Power Transmission Project (03) Energy Managem...

# %%
republics[republics['boardapprovaldate']=="1983-07-26"]
# Out:
#                     regionname             countryname  \
# 13048  Europe and Central Asia  Bosnia and Herzegovina
# 13050  Europe and Central Asia               Macedonia
# 13049  Europe and Central Asia     Republic of Croatia
#
#                    lendinginstr  totalamt         boardapprovaldate location  \
# 13048  Specific Investment Loan         0 1983-07-26 00:00:00+00:00      NaN
# 13050  Specific Investment Loan         0 1983-07-26 00:00:00+00:00      NaN
# 13049  Specific Investment Loan         0 1983-07-26 00:00:00+00:00      NaN
#
#       GeoLocID GeoLocName Latitude Longitude Country     project_name
# 13048      NaN        NaN      NaN       NaN     NaN  POWER TRANS.III
# 13050      NaN        NaN      NaN       NaN     NaN  POWER TRANS.III
# 13049      NaN        NaN      NaN       NaN     NaN  POWER TRANS.III

# %% [markdown]
# # Conclusion
#
# On July 26th, 1983, for example, projects were approved for Bosnia and Herzegovina, Croatia, Macedonia, Slovenia, and Yugoslavia. The code below shows the projects for that date. You'll notice that Yugoslavia had two projects, one of which was called "Power Transmission Project (03) Energy Managem...". The projects in the other countries were all called "POWER TRANS.III".
#
# This looks like a case of duplicate data. What you end up doing with this knowledge would depend on the context. For example, if you wanted to get a true count for the total number of projects in the data set, should all of these projects be counted as one project?
#
# Run the code cell below to see the projects in question.

# %%
import datetime

# run this code cell to see the duplicate data
pd.concat([yugoslavia[yugoslavia['boardapprovaldate'] == datetime.date(1983, 7, 26)], republics[republics['boardapprovaldate'] == datetime.date(1983, 7, 26)]])
# Out:
# /root/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and 'the values will not compare equal to the
# 'datetime.date'. To retain the current behavior, convert the
# 'datetime.date' to a datetime with 'pd.Timestamp'.
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-53385f724a93> in <module>
#       2
#       3 # run this code cell to see the duplicate data
# ----> 4 pd.concat([yugoslavia[yugoslavia['boardapprovaldate'] == datetime.date(1983, 7, 26)], republics[republics['boardapprovaldate'] == datetime.date(1983, 7, 26)]])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1714
#    1715             res_values = dispatch_to_index_op(op, self, other,
# -> 1716                                               pd.DatetimeIndex)
#    1717
#    1718             return self._constructor(res_values, index=self.index,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in dispatch_to_index_op(op, left, right, index_class)
#    1189         left_idx = left_idx._shallow_copy(freq=None)
#    1190     try:
# -> 1191         result = op(left_idx, right)
#    1192     except NullFrequencyError:
#    1193         # DatetimeIndex and TimedeltaIndex with freq == None raise ValueError
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/datetimelike.py in wrapper(self, other)
#     115                 other = other._values
#     116
# --> 117             result = op(self._data, maybe_unwrap_index(other))
#     118             return result
#     119
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in wrapper(self, other)
#     140             if isinstance(other, (datetime, np.datetime64)):
#     141                 # GH#18435 strings get a pass from tzawareness compat
# --> 142                 self._assert_tzawareness_compat(other)
#     143
#     144             try:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in _assert_tzawareness_compat(self, other)
#     698                                 'datetime-like objects.')
#     699         elif other_tz is None:
# --> 700             raise TypeError('Cannot compare tz-naive and tz-aware '
#     701                             'datetime-like objects')
#     702
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects
