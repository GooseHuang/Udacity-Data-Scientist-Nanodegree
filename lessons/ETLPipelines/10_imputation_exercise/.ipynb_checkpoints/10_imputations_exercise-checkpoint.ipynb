# %% [markdown]
# # Imputing Data
#
# When a dataset has missing values, you can either remove those values or fill them in. In this exercise, you'll work with World Bank GDP (Gross Domestic Product) data to fill in missing values.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# run this code cell to read in the data set
import pandas as pd
df = pd.read_csv('../data/gdp_data.csv', skiprows=4)
df.drop('Unnamed: 62', axis=1, inplace=True)

# %%
# run this code cell to see what the data looks like
df.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code          1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  5.377778e+08
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD           NaN
#
#            1961          1962          1963          1964          1965  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
#            2008          2009          2010          2011          2012  \
# 0  2.791961e+09  2.498933e+09  2.467704e+09  2.584464e+09           NaN
# 1  1.019053e+10  1.248694e+10  1.593680e+10  1.793024e+10  2.053654e+10
# 2  8.417804e+10  7.549239e+10  8.252614e+10  1.041158e+11  1.139232e+11
# 3  1.288135e+10  1.204421e+10  1.192695e+10  1.289087e+10  1.231978e+10
# 4  4.007353e+09  3.660531e+09  3.355695e+09  3.442063e+09  3.164615e+09
#
#            2013          2014          2015          2016          2017
# 0           NaN           NaN           NaN           NaN           NaN
# 1  2.026425e+10  2.061610e+10  1.921556e+10  1.946902e+10  2.081530e+10
# 2  1.249125e+11  1.267302e+11  1.026212e+11  9.533720e+10  1.242094e+11
# 3  1.277628e+10  1.322824e+10  1.138693e+10  1.188368e+10  1.303935e+10
# 4  3.281585e+09  3.350736e+09  2.811489e+09  2.877312e+09  3.012914e+09
#
# [5 rows x 62 columns]

# %%
# Run this code cell to check how many null values are in the data set
df.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              140
# 1961              140
# 1962              139
# 1963              139
# 1964              139
# 1965              128
# 1966              127
# 1967              123
# 1968              119
# 1969              119
# 1970              111
# 1971              109
# 1972              109
# 1973              109
# 1974              108
# 1975              104
# 1976              103
# 1977               99
# 1978              100
# 1979               99
# 1980               87
# 1981               83
# 1982               77
# 1983               76
# 1984               74
# 1985               72
#                  ...
# 1988               64
# 1989               60
# 1990               44
# 1991               50
# 1992               47
# 1993               42
# 1994               37
# 1995               28
# 1996               27
# 1997               28
# 1998               26
# 1999               25
# 2000               19
# 2001               19
# 2002               15
# 2003               15
# 2004               14
# 2005               14
# 2006               13
# 2007               13
# 2008               15
# 2009               15
# 2010               15
# 2011               14
# 2012               17
# 2013               16
# 2014               17
# 2015               18
# 2016               23
# 2017               30
# Length: 62, dtype: int64

# %% [markdown]
# There are quite a few null values. Run the code below to plot the data for a few countries in the data set.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# put the data set into long form instead of wide
df_melt = pd.melt(df, id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], var_name='year', value_name='GDP')

# convert year to a date time
df_melt['year'] = pd.to_datetime(df_melt['year'])

def plot_results(column_name):
    # plot the results for Afghanistan, Albania, and Honduras
    fig, ax = plt.subplots(figsize=(8,6))

    df_melt[(df_melt['Country Name'] == 'Afghanistan') | 
            (df_melt['Country Name'] == 'Albania') | 
            (df_melt['Country Name'] == 'Honduras')].groupby('Country Name').plot('year', column_name, legend=True, ax=ax)
    ax.legend(labels=['Afghanistan', 'Albania', 'Honduras'])
    
plot_results('GDP')

# %% [markdown]
# Afghanistan and Albania are missing data, which show up as gaps in the results.

# %% [markdown]
# # Exercise - Part 1
#
# Your first task is to calculate mean GDP for each country and fill in missing values with the country mean. This is a bit tricky to do in pandas. Here are a few links that should be helpful:
# * https://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.DataFrame.groupby.html
# * https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.transform.html
# * https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.DataFrame.fillna.html

# %%
df_melt.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code       year  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
#
#             GDP
# 0           NaN
# 1  5.377778e+08
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# TODO: Use the df_melt dataframe and fill in missing values with a country's mean GDP
# If aren't sure how to do this, 
# look up something like "how to group data and fill in nan values in pandas" in a search engine
# Put the results in a new column called 'GDP_filled'.


df_melt['GDP_filled'] = df_melt.groupby('Country Name')['GDP'].transform(lambda x: x.fillna(x.mean()))

# %%
df_melt.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code       year  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
#
#             GDP    GDP_filled
# 0           NaN  2.036355e+09
# 1  5.377778e+08  5.377778e+08
# 2           NaN  3.847557e+10
# 3           NaN  6.220172e+09
# 4           NaN  1.501056e+09

# %%
# Plot the results
plot_results('GDP_filled')

# %% [markdown]
# This is somewhat of an improvement. At least there is no missing data; however, because GDP tends to increase over time, the mean GDP is probably not the best way to fill in missing values for this particular case. Next, try using forward fill to deal with any missing values.

# %% [markdown]
# # Excercise - Part 2
#
# Use the fillna forward fill method to fill in the missing data. Here is the [documentation](https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.DataFrame.fillna.html). As explained in the course video, forward fill takes previous values to fill in nulls.
#
# The pandas fillna method has a forward fill option. For example, if you wanted to use forward fill on the GDP dataset, you could execute `df_melt['GDP'].fillna(method='ffill')`. However, there are two issues with that code.
# 1. You want to first make sure the data is sorted by year
# 2. You need to group the data by country name so that the forward fill stays within each country
#
# Write code to first sort the df_melt dataframe by year, then group by 'Country Name', and finally use the forward fill method.

# %%
df_melt.sort_values('year').groupby('Country Name')['GDP'].fillna(method='ffill')
# Out:
# 0                 NaN
# 167      1.916242e+09
# 168      5.844779e+11
# 169               NaN
# 170               NaN
# 171      4.495269e+08
# 172      4.196092e+09
# 173               NaN
# 174      1.227673e+10
# 175      5.163272e+09
# 176      5.083344e+08
# 177               NaN
# 178      5.485855e+09
# 179      1.072374e+12
# 180               NaN
# 181               NaN
# 182      3.707056e+09
# 183      5.371471e+08
# 184      2.571908e+09
# 185      6.684569e+09
# 186               NaN
# 187      2.304960e+08
# 188               NaN
# 189      8.428018e+09
# 190      1.691900e+09
# 191               NaN
# 192      3.193200e+09
# 193               NaN
# 194               NaN
# 195               NaN
#              ...
# 15116    1.311320e+12
# 15117    2.592108e+10
# 15118    8.056150e+10
# 15119    1.727770e+13
# 15120    8.307268e+11
# 15121    2.518849e+11
# 15122    5.061203e+09
# 15123    2.582501e+12
# 15124    2.476746e+09
# 15125    3.364275e+08
# 15126    1.462288e+10
# 15127    2.622434e+12
# 15178    5.098436e+10
# 15128    1.515928e+10
# 15130             NaN
# 15131    1.049147e+10
# 15132    1.014622e+09
# 15133    1.346933e+09
# 15134    1.248675e+10
# 15135    2.002883e+11
# 15136    1.118817e+09
# 15137    2.705892e+09
# 15138    7.562010e+10
# 15139    5.793000e+09
# 15140    3.675632e+09
# 15141    5.147541e+13
# 15142    3.414493e+11
# 15143    2.297853e+10
# 15129    4.733002e+10
# 15311    1.784582e+10
# Name: GDP, Length: 15312, dtype: float64

# %%
df_melt.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code       year  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
#
#             GDP    GDP_filled
# 0           NaN  2.036355e+09
# 1  5.377778e+08  5.377778e+08
# 2           NaN  3.847557e+10
# 3           NaN  6.220172e+09
# 4           NaN  1.501056e+09

# %%
df_melt.sort_values([])

# %%
# TODO: Use forward fill to fill in missing GDP values
# HINTS: use the sort_values(), groupby(), and fillna() methods

df_melt['GDP_ffill'] = df_melt.sort_values('year').groupby('Country Name')['GDP'].fillna(method='ffill')

# %%
df_melt.iloc[150:200,:]
# Out:
#                                           Country Name Country Code  \
# 150                                           Maldives          MDV
# 151                         Middle East & North Africa          MEA
# 152                                             Mexico          MEX
# 153                                   Marshall Islands          MHL
# 154                                      Middle income          MIC
# 155                                     Macedonia, FYR          MKD
# 156                                               Mali          MLI
# 157                                              Malta          MLT
# 158                                            Myanmar          MMR
# 159  Middle East & North Africa (excluding high inc...          MNA
# 160                                         Montenegro          MNE
# 161                                           Mongolia          MNG
# 162                           Northern Mariana Islands          MNP
# 163                                         Mozambique          MOZ
# 164                                         Mauritania          MRT
# 165                                          Mauritius          MUS
# 166                                             Malawi          MWI
# 167                                           Malaysia          MYS
# 168                                      North America          NAC
# 169                                            Namibia          NAM
# 170                                      New Caledonia          NCL
# 171                                              Niger          NER
# 172                                            Nigeria          NGA
# 173                                          Nicaragua          NIC
# 174                                        Netherlands          NLD
# 175                                             Norway          NOR
# 176                                              Nepal          NPL
# 177                                              Nauru          NRU
# 178                                        New Zealand          NZL
# 179                                       OECD members          OED
# 180                                               Oman          OMN
# 181                                 Other small states          OSS
# 182                                           Pakistan          PAK
# 183                                             Panama          PAN
# 184                                               Peru          PER
# 185                                        Philippines          PHL
# 186                                              Palau          PLW
# 187                                   Papua New Guinea          PNG
# 188                                             Poland          POL
# 189                           Pre-demographic dividend          PRE
# 190                                        Puerto Rico          PRI
# 191                          Korea, Dem. People’s Rep.          PRK
# 192                                           Portugal          PRT
# 193                                           Paraguay          PRY
# 194                                 West Bank and Gaza          PSE
# 195                        Pacific island small states          PSS
# 196                          Post-demographic dividend          PST
# 197                                   French Polynesia          PYF
# 198                                              Qatar          QAT
# 199                                            Romania          ROU
#
#         Indicator Name  Indicator Code       year           GDP    GDP_filled  \
# 150  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  1.235325e+09
# 151  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  1.103623e+12
# 152  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  1.304000e+10  1.304000e+10
# 153  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  1.159689e+08
# 154  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  2.871190e+11  2.871190e+11
# 155  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  6.575914e+09
# 156  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  4.340053e+09
# 157  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  4.141677e+09
# 158  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  3.589124e+10
# 159  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  8.885912e+11
# 160  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  3.310724e+09
# 161  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  4.204709e+09
# 162  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  9.695333e+08
# 163  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  6.608543e+09
# 164  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  9.260922e+07  9.260922e+07
# 165  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  5.156350e+09
# 166  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  1.629567e+08  1.629567e+08
# 167  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  1.916242e+09  1.916242e+09
# 168  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  5.844779e+11  5.844779e+11
# 169  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  5.786257e+09
# 170  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  1.497461e+09
# 171  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  4.495269e+08  4.495269e+08
# 172  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  4.196092e+09  4.196092e+09
# 173  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  6.512962e+09
# 174  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  1.227673e+10  1.227673e+10
# 175  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  5.163272e+09  5.163272e+09
# 176  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  5.083344e+08  5.083344e+08
# 177  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  7.926333e+07
# 178  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  5.485855e+09  5.485855e+09
# 179  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  1.072374e+12  1.072374e+12
# 180  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  2.132977e+10
# 181  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  1.423526e+11
# 182  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  3.707056e+09  3.707056e+09
# 183  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  5.371471e+08  5.371471e+08
# 184  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  2.571908e+09  2.571908e+09
# 185  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  6.684569e+09  6.684569e+09
# 186  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  2.040715e+08
# 187  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  2.304960e+08  2.304960e+08
# 188  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  2.998720e+11
# 189  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  8.428018e+09  8.428018e+09
# 190  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  1.691900e+09  1.691900e+09
# 191  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN           NaN
# 192  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  3.193200e+09  3.193200e+09
# 193  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  8.654169e+09
# 194  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  6.976688e+09
# 195  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  4.072052e+09
# 196  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01  1.042816e+12  1.042816e+12
# 197  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  1.818946e+09
# 198  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  4.281256e+10
# 199  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01           NaN  9.667009e+10
#
#         GDP_ffill
# 150           NaN
# 151           NaN
# 152  1.304000e+10
# 153           NaN
# 154  2.871190e+11
# 155           NaN
# 156           NaN
# 157           NaN
# 158           NaN
# 159           NaN
# 160           NaN
# 161           NaN
# 162           NaN
# 163           NaN
# 164  9.260922e+07
# 165           NaN
# 166  1.629567e+08
# 167  1.916242e+09
# 168  5.844779e+11
# 169           NaN
# 170           NaN
# 171  4.495269e+08
# 172  4.196092e+09
# 173           NaN
# 174  1.227673e+10
# 175  5.163272e+09
# 176  5.083344e+08
# 177           NaN
# 178  5.485855e+09
# 179  1.072374e+12
# 180           NaN
# 181           NaN
# 182  3.707056e+09
# 183  5.371471e+08
# 184  2.571908e+09
# 185  6.684569e+09
# 186           NaN
# 187  2.304960e+08
# 188           NaN
# 189  8.428018e+09
# 190  1.691900e+09
# 191           NaN
# 192  3.193200e+09
# 193           NaN
# 194           NaN
# 195           NaN
# 196  1.042816e+12
# 197           NaN
# 198           NaN
# 199           NaN

# %%
df = df_melt[(df_melt['Country Name'] == 'Afghanistan') | 
            (df_melt['Country Name'] == 'Albania') | 
            (df_melt['Country Name'] == 'Honduras')]

# %%
df['GDP'].mean()
# Out:
# 6236998742.2060175

# %%
df[df['Country Name']=='Afghanistan']
# Out:
#       Country Name Country Code     Indicator Name  Indicator Code       year  \
# 1      Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 265    Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1961-01-01
# 529    Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1962-01-01
# 793    Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1963-01-01
# 1057   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1964-01-01
# 1321   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1965-01-01
# 1585   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1966-01-01
# 1849   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1967-01-01
# 2113   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1968-01-01
# 2377   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1969-01-01
# 2641   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1970-01-01
# 2905   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1971-01-01
# 3169   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1972-01-01
# 3433   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1973-01-01
# 3697   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1974-01-01
# 3961   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1975-01-01
# 4225   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1976-01-01
# 4489   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1977-01-01
# 4753   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1978-01-01
# 5017   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1979-01-01
# 5281   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1980-01-01
# 5545   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1981-01-01
# 5809   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1982-01-01
# 6073   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1983-01-01
# 6337   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1984-01-01
# 6601   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1985-01-01
# 6865   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1986-01-01
# 7129   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1987-01-01
# 7393   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1988-01-01
# 7657   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1989-01-01
# 7921   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1990-01-01
# 8185   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1991-01-01
# 8449   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1992-01-01
# 8713   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1993-01-01
# 8977   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1994-01-01
# 9241   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1995-01-01
# 9505   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1996-01-01
# 9769   Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1997-01-01
# 10033  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1998-01-01
# 10297  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1999-01-01
# 10561  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2000-01-01
# 10825  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2001-01-01
# 11089  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2002-01-01
# 11353  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2003-01-01
# 11617  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2004-01-01
# 11881  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2005-01-01
# 12145  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2006-01-01
# 12409  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2007-01-01
# 12673  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2008-01-01
# 12937  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2009-01-01
# 13201  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2010-01-01
# 13465  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2011-01-01
# 13729  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2012-01-01
# 13993  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2013-01-01
# 14257  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2014-01-01
# 14521  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2015-01-01
# 14785  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2016-01-01
# 15049  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 2017-01-01
#
#                 GDP    GDP_filled     GDP_ffill
# 1      5.377778e+08  5.377778e+08  5.377778e+08
# 265    5.488889e+08  5.488889e+08  5.488889e+08
# 529    5.466667e+08  5.466667e+08  5.466667e+08
# 793    7.511112e+08  7.511112e+08  7.511112e+08
# 1057   8.000000e+08  8.000000e+08  8.000000e+08
# 1321   1.006667e+09  1.006667e+09  1.006667e+09
# 1585   1.400000e+09  1.400000e+09  1.400000e+09
# 1849   1.673333e+09  1.673333e+09  1.673333e+09
# 2113   1.373333e+09  1.373333e+09  1.373333e+09
# 2377   1.408889e+09  1.408889e+09  1.408889e+09
# 2641   1.748887e+09  1.748887e+09  1.748887e+09
# 2905   1.831109e+09  1.831109e+09  1.831109e+09
# 3169   1.595555e+09  1.595555e+09  1.595555e+09
# 3433   1.733333e+09  1.733333e+09  1.733333e+09
# 3697   2.155555e+09  2.155555e+09  2.155555e+09
# 3961   2.366667e+09  2.366667e+09  2.366667e+09
# 4225   2.555556e+09  2.555556e+09  2.555556e+09
# 4489   2.953333e+09  2.953333e+09  2.953333e+09
# 4753   3.300000e+09  3.300000e+09  3.300000e+09
# 5017   3.697940e+09  3.697940e+09  3.697940e+09
# 5281   3.641723e+09  3.641723e+09  3.641723e+09
# 5545   3.478788e+09  3.478788e+09  3.478788e+09
# 5809            NaN  6.620578e+09  3.478788e+09
# 6073            NaN  6.620578e+09  3.478788e+09
# 6337            NaN  6.620578e+09  3.478788e+09
# 6601            NaN  6.620578e+09  3.478788e+09
# 6865            NaN  6.620578e+09  3.478788e+09
# 7129            NaN  6.620578e+09  3.478788e+09
# 7393            NaN  6.620578e+09  3.478788e+09
# 7657            NaN  6.620578e+09  3.478788e+09
# 7921            NaN  6.620578e+09  3.478788e+09
# 8185            NaN  6.620578e+09  3.478788e+09
# 8449            NaN  6.620578e+09  3.478788e+09
# 8713            NaN  6.620578e+09  3.478788e+09
# 8977            NaN  6.620578e+09  3.478788e+09
# 9241            NaN  6.620578e+09  3.478788e+09
# 9505            NaN  6.620578e+09  3.478788e+09
# 9769            NaN  6.620578e+09  3.478788e+09
# 10033           NaN  6.620578e+09  3.478788e+09
# 10297           NaN  6.620578e+09  3.478788e+09
# 10561           NaN  6.620578e+09  3.478788e+09
# 10825  2.461666e+09  2.461666e+09  2.461666e+09
# 11089  4.128821e+09  4.128821e+09  4.128821e+09
# 11353  4.583644e+09  4.583644e+09  4.583644e+09
# 11617  5.285466e+09  5.285466e+09  5.285466e+09
# 11881  6.275074e+09  6.275074e+09  6.275074e+09
# 12145  7.057598e+09  7.057598e+09  7.057598e+09
# 12409  9.843842e+09  9.843842e+09  9.843842e+09
# 12673  1.019053e+10  1.019053e+10  1.019053e+10
# 12937  1.248694e+10  1.248694e+10  1.248694e+10
# 13201  1.593680e+10  1.593680e+10  1.593680e+10
# 13465  1.793024e+10  1.793024e+10  1.793024e+10
# 13729  2.053654e+10  2.053654e+10  2.053654e+10
# 13993  2.026425e+10  2.026425e+10  2.026425e+10
# 14257  2.061610e+10  2.061610e+10  2.061610e+10
# 14521  1.921556e+10  1.921556e+10  1.921556e+10
# 14785  1.946902e+10  1.946902e+10  1.946902e+10
# 15049  2.081530e+10  2.081530e+10  2.081530e+10

# %%
# plot the results
plot_results('GDP_ffill')

# %% [markdown]
# This looks better at least for the Afghanistan data; however, the Albania data is still missing values. You can fill in the Albania data using back fill. That is what you'll do next.

# %% [markdown]
# # Exercise - Part 3
#
# This part is similar to Part 2, but now you will use backfill. Write code that backfills the missing GDP data.

# %%
# TODO: Use back fill to fill in missing GDP values
# HINTS: use the sort_values(), groupby(), and fillna() methods

df_melt['GDP_bfill'] = df_melt.sort_values('year').groupby('Country Name')['GDP'].fillna(method='bfill')

# %%
# plot the results
plot_results('GDP_bfill')

# %% [markdown]
# # Conclusion
#
# In this case, the GDP data for all three countries is now complete. Note that forward fill did not fill all the Albania data because the first data entry in 1960 was NaN. Forward fill would try to fill the 1961 value with the NaN value from 1960.
#
# To completely fill the entire GDP data for all countries, you might have to run both forward fill and back fill. Note as well that the results will be slightly different depending on if you run forward fill first or back fill first. Afghanistan, for example, is missing data in the middle of the data set. Hence forward fill and back fill will have slightly different results.
#
# Run this next code cell to see if running both forward fill and back fill end up filling all the GDP NaN values.

# %%
# Run forward fill and backward fill on the GDP data
df_melt['GDP_ff_bf'] = df_melt.sort_values('year').groupby('Country Name')['GDP'].fillna(method='ffill').fillna(method='bfill')

# Check if any GDP values are null
df_melt['GDP_ff_bf'].isnull().sum()
# Out:
# 0
